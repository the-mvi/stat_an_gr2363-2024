# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2363 Курбатов Иван Максимович. Вариант №7

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормального распределения, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
# Плотность нормального случайного вектора: $ \quad \rho_{\xi,\eta}(x, y) = \frac{1}{2\pi^{\frac{n}{2}} \sqrt{\frac{1}{\left|\Sigma^{-1}\right|}}}\exp\left((-\frac{1}{2}\left(\vec{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\vec{x}-\mu\right)\right) $
#
# $ \vec{\xi} \sim \mathcal{N}(\mu, \Sigma), \quad \vec{\xi}=\left(\xi_1, \xi_2, \ldots, \xi_n\right)^{\intercal}, \quad A_n, \quad \vec{b}=\left(b_1, b_2, \ldots, b_n\right)^{\intercal}, \quad \eta=A\vec{\xi}+b \sim {N}\left(A\mu+b,A \Sigma A^{\intercal}\right). $

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
# Плотность двумерного нормального распределения имеет вид:
# $
# \quad \rho_{\xi,\eta}(x, y) = С\cdot\exp\left(-\frac{1}{2}\left(2x^2-4xy+5y^2-4x-2y+5\right)\right)
# $
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения$ \rho_{\xi,\eta} $.
#    $ q(x, y)=2x^2-4xy+5y^2-4x-2y+5=2((x-y)-1)^2+3(y-1)^2=2(x-2)^2+2\cdot(-2)(x-2)(y-1)+5(y-1)^2 $
#
#    Мат. ожидание:  $ \mathbb{E} \begin{pmatrix}\xi \\ \eta \end{pmatrix}=\begin{pmatrix} 2 \\ 1 \end{pmatrix}; $
#
#    Обратная матрица ковариаций: $ \Sigma^{-1}=\begin{pmatrix}2 & -2 \\ -2 & 5\end{pmatrix} $
#
#    Матрица ковариаций: $ \Sigma=\frac{1}{6}\begin{pmatrix}5 & 2 \\ 2 & 2\end{pmatrix}; $
#
#    Дисперсия: $ \mathbb{D}\eta=\frac{1}{3}, \quad \mathbb{D}\xi=\frac{5}{6}; $
#
#    Ковариация: $ \mathop{\mathrm{cov}}\nolimits(\xi, \eta)=\frac{1}{3}; $
#
#    Коэффицент корреляции: $ \rho(\xi, \eta)=\frac{\sqrt{2}}{5}. $
#
#    Константа: $ C=\frac{1}{2\pi\sqrt{\frac{1}{6}}} $

# %%
# !pip install matplotlib
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
x = np.linspace(-10, 10, 500)
y = np.linspace(-10, 10, 500)
X, Y = np.meshgrid(x, y)
Z = (1/(2*np.pi*np.sqrt(1/6)))*np.exp(-0.5*(2*X**2-4*X*Y+5*Y**2-4*X-2*Y+5))
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
plt.title('График плотности двумерного нормального распределения')
plt.show()

# %% [markdown]
# 2. Найти аффиное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#    $ q(x,y)=2((x-y)-1)^2+3(y-1)^2=(\sqrt{2}(x-y)-\sqrt{2})^2+(\sqrt{3}y-\sqrt{3})^2 $
#
#    Аффиное преобразование: $ \begin{pmatrix}\xi_{st}  \eta_{st} \end{pmatrix}=\begin{pmatrix} \sqrt{2} & -\sqrt{2} \\ 0 & \sqrt{3}\end{pmatrix} \cdot \begin{pmatrix}\xi \\ \eta \end{pmatrix}+\begin{pmatrix}-\sqrt{2} \\ -\sqrt{3} \end{pmatrix}. $
#
#    Проверка:
#
#    $ A\vec{\xi}+b\sim{N}\left(A\mathbb{E}+b,A \mathbb{E} A^{\intercal}\right); $
#
#    $ \mathbb{E}\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix}=\begin{pmatrix} \sqrt{2} & -\sqrt{2} \\ 0 & \sqrt{3} \end{pmatrix} \cdot \begin{pmatrix} 2 \\ 1 \end{pmatrix} + \begin{pmatrix} -\sqrt{2} \\ -\sqrt{3} \end{pmatrix}=\begin{pmatrix} \sqrt{2} \\ \sqrt{3}\end{pmatrix} + \begin{pmatrix} -\sqrt{2} \\ -\sqrt{3} \end{pmatrix}=\begin{pmatrix} 0 \\ 0 \end{pmatrix} $
#
#    $ \Sigma_{st}=\frac{1}{6}\begin{pmatrix} \sqrt{2} & -\sqrt{2} \\ 0 & \sqrt{3} \end{pmatrix} \begin{pmatrix} 5 & 2 \\ 2 & 2 \end{pmatrix} \begin{pmatrix} \sqrt{2} & 0 \\ -\sqrt{2} & \sqrt{3} \end{pmatrix}=\frac{1}{6} \begin{pmatrix} 3\sqrt{2} & 0 \\ 2\sqrt{3} & 2\sqrt{3} \end{pmatrix} \begin{pmatrix} \sqrt{2} & 0 \\ -\sqrt{2} & \sqrt{3} \end{pmatrix}= \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}. $
#
#    Получен нулевой вектор и  единичная матрица, значит проверка выполнена успешно.

# %% [markdown]
# 3. Найти ортогональное преобразование, переводящее соответсвующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
#
#     $ \begin{vmatrix} \begin{pmatrix} 2 & -2 \\ -2 & 5 \end{pmatrix} - \begin{pmatrix} \lambda & 0 \\ 0 & \lambda \end{pmatrix} \end{vmatrix}= \begin{vmatrix} 2-\lambda & -2 \\ -2 & 5-\lambda \end{vmatrix}=0 $
#
#     $ \left(2-\lambda\right)\left(5-\lambda\right)-(-2)\cdot(-2)=0 $
#
#     $ \lambda^2-7\lambda+6=0 $
#
#     $ \lambda_1=6, \quad \lambda_2=1. $
#
#     $ \left\{\begin{array}-4u_1-2v_1=0, \\ -2u_1-v_1=0; \end{array}\right. $
#
#     $ \left\{\begin{array}  -u_1 \in \mathbb{R} \\  v_1=-2u_1; \end{array}\right. $
#
#     $ \vec{{u}_{1}}= \begin{pmatrix} 1 \\ -2 \end{pmatrix}\alpha, \quad \vec{v_{1}}= \frac{1}{\sqrt{5}}\begin{pmatrix} 1 \\ -2 \end{pmatrix}; $
#
#     $ \left\{\begin{array}-u_2-2v_2=0, \\ -2u_2+4v_2=0; \end{array}\right. $
#
#     $ \left\{\begin{array}  -v_2 \in \mathbb{R} \\  u_2=2v_2; \end{array}\right. $
#
#     $ \vec{v_{2}}= \begin{pmatrix} 2 \\ 1 \end{pmatrix}\beta, \quad \vec{u_{2}}= \frac{1}{\sqrt{5}}\begin{pmatrix} 2 \\ 1 \end{pmatrix}; $
#
#     $ Q^{\intercal}=\frac{1}{\sqrt{5}} \begin{pmatrix} 1 & 2 \\ -2 & 1 \end{pmatrix}, \quad Q= \frac{1}{\sqrt{5}}\begin{pmatrix} 1 & -2 \\ 2 & 1 \end{pmatrix} $
#
#     Проверка:
#
#     $Q \Sigma Q^{\intercal}=\begin{pmatrix} \frac{1}{\lambda_1} & 0 \\ 0 & \frac{1}{\lambda_2} \end{pmatrix}$
#
#     $ \frac{1}{\sqrt{5}}\begin{pmatrix} 1 & -2 \\ 2 & 1 \end{pmatrix} \frac{1}{6} \begin{pmatrix} 5 & 2 \\ 2 & 2 \end{pmatrix} \frac{1}{\sqrt{5}}\begin{pmatrix} 1 & 2 \\ -2 & 1 \end{pmatrix}=\frac{1}{30} \begin{pmatrix} 1 & -2 \\ 12 & 6 \end{pmatrix} \begin{pmatrix} 1 & 2 \\ -2 & 1 \end{pmatrix}= \begin{pmatrix} \frac{1}{6} & 0 \\ 0 & 1 \end{pmatrix}, $
#
#    На главной диагонали матрицы обратные собственные числа, значит наше решение верное.
#
#     $ \vec{\mu_2} = Q \cdot \vec{\mu_1} = \frac{1}{\sqrt{5}} \cdot \begin{pmatrix} 1 & -2 \\ 2 & 1\end{pmatrix} \begin{pmatrix} 2 \\ 1 \end{pmatrix} = \begin{pmatrix} 0 \\ \sqrt{5} \end{pmatrix}  $
#
#    $ \rho_{\xi_{id},\eta_{id}}(x,y)= \frac{\sqrt{6}}{2\pi}\cdot \exp\left(-\frac{1}{2}\left(6x^2+y^2 - 2\sqrt{5}+5\right)\right) $

# %%
# !pip install matplotlib
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
x = np.linspace(-25, 25, 1000)
y = np.linspace(-25, 25, 1000)
X, Y = np.meshgrid(x, y)
Z = (np.sqrt(6)/(2*np.pi))*np.exp(-0.5*(1/6*X**2+Y**2+2*np.sqrt(5)+5))
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
plt.title('График плотности полученного распределения')
plt.show()

# %% [markdown]
# 4. Вычислить характеристики совместного распределения случайного вектора $ (3\xi-2\eta, \xi-\eta)^{\intercal} $ и записать его плотность. Построить график плотности полученного распределения.
#
#    $ \vec{z}= \begin{pmatrix} 3\xi & -2\eta \\ \xi & -\eta \end{pmatrix}, \quad $ $ \vec{z} \sim \left(A\mu + b, A\Sigma{A}^{\intercal}\right) $
#
#    $ A=\begin{pmatrix} 3 & -2 \\ 1 & -1 \end{pmatrix}, \quad b=0 $
#
#    $ \mathbb{E}_z=A{\mu}= \begin{pmatrix} 3 & -2 \\ 1 & -1 \end{pmatrix} \begin{pmatrix} 2 \\ 1 \end{pmatrix} = \begin{pmatrix} 4 \\ 1 \end{pmatrix} $
#
#    $ \Sigma_{z}=A\Sigma{A}^{\intercal}= \begin{pmatrix} 3 & -2 \\ 1 & -1 \end{pmatrix} \frac{1}{6} \begin{pmatrix} 5 & 2 \\ 2 & 2 \end{pmatrix} \begin{pmatrix} 3 & 1 \\ -2 & -1 \end{pmatrix}=\frac{1}{6}\begin{pmatrix} 29 & 9 \\ 9 & 3 \end{pmatrix}   $
#
#    $ \rho_z(z_1,z_2)=\frac{1}{2\pi\sqrt{|\Sigma_{z}|}}exp\left(-\frac{1}{2}\left(\vec{z}-\mu_{z}\right)^{\intercal}\Sigma^{-1}_{z}\left(\vec{z}-\mu_{z}\right)\right)=\frac{1}{2\pi}exp\left(-\frac{1}{2}\left(\begin{pmatrix} x \\ y \end{pmatrix}-\begin{pmatrix}4 \\ 1 \end{pmatrix}\right)^{\intercal}\cdot\frac{1}{6}\begin{pmatrix} 3 & -9 \\ -9 & 29\end{pmatrix}\left( \begin{pmatrix}x \\ y \end{pmatrix} - \begin{pmatrix}4 \\ 1 \end{pmatrix}\right)\right)=$
#
#    $ \rho_z(z_1,z_2)=\frac{1}{2\pi}\exp\left(-\frac{1}{2}\left(3x^2-6x+5-18xy+14y+29y^2\right)\right) $

# %%
# !pip install matplotlib
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
x = np.linspace(-1, 1, 300)
y = np.linspace(-1, 1, 300)
X, Y = np.meshgrid(x, y)
Z = (1/(2*np.pi))*np.exp(-0.5*(3*X**2-6*X+5-18*X*Y+14*Y+29*Y**2))
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.coolwarm)
plt.title('График плотности полученного распределения')
plt.show()

# %% [markdown]
# 5. Найти условное распределение $ \xi $ при условие $ \eta $. Вычислить $ \mathbb{E}\left(\xi|\eta\right) $ и $ \mathbb{D}\left(\xi|\eta\right) $
#
#    $ \rho_{\xi}(\eta=y_0|x)=\frac{\rho(\xi,\eta)(x, y_0)}{\rho_{\eta}(y_0)}=\frac{1}{2\pi\sqrt{\frac{1}{3}}}\exp\left(-\frac{1}{2}\left(2x^2-4xy_0+5y^2_0-4x-2y_0+5\right)\right){\frac{1}{2\pi}\cdot\sqrt{\frac{1}{3}}\exp\left(-\frac{1}{2}\left(\frac{y_0-1}{\sqrt{\frac{1}{3}}}\right)^2\right)}=\frac{\sqrt{6\pi}}{2\pi\sqrt{\frac{1}{6}}}\exp\left(-\frac{1}{2}\left(2x^2-4xy_0+5y_0^2-4x-2y_0+5-3y^2_0+6y_0-3\right)\right) $
#
#    $ 2x^2-4xy_0+2y_0^2-4x+4y_0+2=2\left(x^2-2xy_0+y_0^2-2x+2y_0+1\right)=2\left(x^2-2x(y_0+1)+(y_0+1)^2\right)=2\left(x+\left(y_0+1\right)\right)^2=\frac{3\sqrt{\pi}}{\pi}\exp\left(-\frac{1}{2}\left(2(x+(y_0+1)\right)^2\right) $
#
#    $ \sigma=\frac{1}{\sqrt{2}}, \quad \mathbb{D}\left(\xi|\eta\right)=\frac{1}{2}, \quad \mathbb{E}\left(\xi|\eta\right)=-(y_0+1) $

# %% [markdown]
# ## Выводы

# %% [markdown]
# В данной работе были исследованы свойства двумерного случайного вектора имеющего нормальное распределения, а также были построены графики плотности распределений при помощи языка программирования Python и библиотеки matplotlib. Благодаря инструментам библиотеки matplotlib, а именно цветовой карте можно легко отследить наивысшую точку на графиках. Больше всго трудностей вызвало задание под номером 5, в котором нужно было вычислить характристики условного распределения. В ходе выполнения получен полезный опыт работы с набором вёрстки LaTex и интерактивным блокнотом JupyterNotebook.
