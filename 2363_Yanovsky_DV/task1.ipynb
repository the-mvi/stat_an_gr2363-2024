# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2363 Яновский Даниил Витальевич. Вариант №20

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Нормальное распределение двумерного случайного вектора определяется функцией плотности:
# $p(\vec{x}) = \frac{1}{2\pi \cdot \sqrt{\begin{vmatrix} \Sigma \end{vmatrix}}} \exp\left( -\frac{1}{2} \cdot (\vec{x} - \vec{\mu})^{\intercal} \cdot \Sigma^{-1} \cdot (\vec{x} - \vec{\mu}) \right)$
# где:\
# $\vec{x} = \begin{pmatrix} \xi \\ \eta \end{pmatrix},$\
# $\vec{\mu} = \mathbb{E}\begin{pmatrix} \xi \\ \eta \end{pmatrix},$\
# $\Sigma = \begin{pmatrix} \mathbb{D}\xi & \mathop{\mathrm{cov}}\limits(\xi, \eta) \\ \mathop{\mathrm{cov}}\limits(\eta, \xi) & \mathbb{D}\eta \end{pmatrix}.$\
# $\quad$\
# Афинное преобразование:\
# $\vec{\xi} \sim \mathcal{N}(\vec{\mu}, \Sigma)$ — исходный случайный вектор;\
# $\vec{\xi}_{st} \sim \mathcal{N}(\vec{\mu}_{st}, \Sigma_{st})$ — стандартный нормальный случайный вектор;\
# $\vec{\xi}_{st} = A \cdot \vec{\xi} + b$ — афинное преобразование случайного вектора;\
# $\vec{\mu}_{st} = A \cdot \vec{\mu} + b$ — получение стандартного нормального вектора математических ожиданий из исходного;\
# $\Sigma_{st} = A \cdot \Sigma \cdot A^{\intercal}$ — получение стандартной нормальной ковариационной матрицы из исходной.\
# $\quad$\
# Ортогональное преобразование, переводящее соответствующий центрированный вектор в вектор с независимыми компонентами:\
# $Q^{\intercal}$ — матрица из собственных векторов матрицы $\Sigma;$\
# При вычислении выражения $Q \cdot \Sigma \cdot Q^{\intercal}$ должна получится матрица $D$ вида: $\begin{pmatrix} \ldots & 0 \\ 0 & \ldots \end{pmatrix};$\
# Матрица $D$ является диагональной матрицей из собственных значений $\Sigma^{-1},$\
# при этом $\Sigma = Q \cdot D^{-1} \cdot Q^{\intercal},$\
# Плотность распределения независимых компонентов центрированного вектора будет иметь вид:\
# $p_{\xi,\eta}(x', y') = \frac{1}{2\pi \cdot \sqrt{\begin{vmatrix} \Sigma \end{vmatrix}}} \cdot \exp\left(-\frac{1}{2} \cdot \left[  \begin{pmatrix} x' & y' \end{pmatrix} \cdot D^{-1} \cdot \begin{pmatrix} x' \\ y' \end{pmatrix} \right]\right)$\
# $\quad$\
# Cовместное распределение случайного вектора:\
# Пусть $\vec{z} = A \cdot \begin{pmatrix} \xi \\ \eta \end{pmatrix}$ — случайный вектор,\
# тогда $\vec{z} \sim \mathcal{N}(A \cdot \vec{\mu}, A \cdot \Sigma \cdot A^{\intercal})$\
# $\quad$

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ## Пункт 1
#
# Дано: $𝛲_{\xi,\eta}(x,y) = 𝐶 ⋅ \exp\left(-\frac{1}{2}\left(3x^2 + 3xy + 7y^2 + 9x + 17y + 13\right)\right)$
#
# Для дальнейших шагов нам необходимо выделить квадратичную форму:
#
# $ 3x^2 + 3xy + 7y^2 + 9x + 17y + 13 = 3\left(x^2 + 2x + 1\right) + 7\left(y^2 + 2y + 1\right) + 3xy + 3x + 3y + 3 = \\ = 3\left(x + 1\right)^2 + 3\left(x + 1\right)\left(y + 1\right) + 7\left(y + 1\right)^2$
#
# Таким образом мы получаем:
#
# $𝛲_{\xi,\eta}(x,y) = 𝐶 ⋅ \exp\left(-\frac{1}{2}\left[3\left(x + 1\right)^2 + 3\left(x + 1\right)\left(y + 1\right) + 7\left(y + 1\right)^2\right]\right)$
#
# Из этой записи мы можем получить матрицу $Σ^{-1}:$
#
# $Σ^{-1} =
# \begin{pmatrix}
#   3 & \frac{3}{2}\\
#   \frac{3}{2} & 7
# \end{pmatrix}$
#
# Получим матрицу $Σ$:
#
# $Σ = \frac{1}{\begin{vmatrix}Σ^{-1}\end{vmatrix}} ⋅
# \begin{pmatrix}
#   7 & -\frac{3}{2}\\
#   -\frac{3}{2} & 3
# \end{pmatrix}
# = \frac{4}{75} ⋅
# \begin{pmatrix}
#   7 & -\frac{3}{2}\\
#   -\frac{3}{2} & 3
# \end{pmatrix}$
#
# Также запишем вектор математических ожиданий $\vecμ_{ξ,η}$:
#
# $\vecμ_{ξ,η} =
# \begin{pmatrix}
#   -1 \\
#   -1
# \end{pmatrix}$
#
# Запишем искомые $C, \mathbb{D}_ξ$, $\mathbb{D}_\eta$, $\mathop{\mathrm{cov}}\nolimits(\xi, \eta)$ и $\rho(\xi, \eta)$:
#
# $
#   𝐶 = \frac{1}{2\pi \cdot \sqrt{\frac{4}{75}}} = \frac{5\sqrt{3}}{4\pi} \\
#   \mathbb{D}_ξ = \frac{4}{75} ⋅ 7 = \frac{28}{75}\\
#   \mathbb{D}_\eta = \frac{4}{75} ⋅ 3 = \frac{4}{25}\\
#   \mathop{\mathrm{cov}}\nolimits(\xi, \eta) = \frac{4}{75} ⋅ \frac{-3}{2} = -\frac{2}{25}\\
#   \rho(\xi, \eta) = \frac{\mathop{\mathrm{cov}}\nolimits(\xi, \eta)}
#   {\sqrt{\mathbb{D}_ξ ⋅ \mathbb{D}_\eta}} = \frac{-\left(\frac{2}{25}\right)}{\sqrt{\left(\frac{28}{75}\right) ⋅ \left(\frac{4}{25}\right)}} = - \frac{\sqrt{21}}{14}\\
# $
#
# Далее построим график плотнсти распределения $𝛲_{\xi,\eta}$:

# %%
P_xi_eta <- function(x, y) {
  5 * sqrt(3) / (4 * pi) * exp(-0.5 * (3 * (x + 1)^2 + 3 * (x + 1) * (y + 1) + 7 * (y + 1)^2))
}

x <- seq(-4, 4, length = 50)
y <- seq(-4, 4, length = 50)
z <- outer(x, y, P_xi_eta)

persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 0, phi = 0)
persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 90, phi = 90)
persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 45, phi = 45)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ##Пункт 2
#
# Необходимо найти афинное преобразование, которое будет переводить исходный случайный вектор в стандартный нормальный.
#
# Для этого необходимо привести квадратичную форму к каноническому виду:
#
# $3\left(x + 1\right)^2 + 3\left(x + 1\right)\left(y + 1\right) + 7\left(y + 1\right)^2 = \left(\sqrt{3}x + \frac{\sqrt{3}}{2}y + \frac{3\sqrt{3}}{2}\right)^2 ⋅ \left(\frac{5}{2}y + \frac{5}{2}\right)^2$
#
# Необходимое преобразование:
#
# $\vec\xi \sim \mathcal{N}(μ, Σ)$
#
# Преобразование будет иметь вид:
#
# $A⋅\vec\xi + \vec{b} \sim \mathcal{N}(A\vec{μ} + \vec{b}, AΣA^{T})$
#
# Коэффициенты для матрицы A и вектора-столбца $\vec{b}$ возьмем из полученной ранее канонической формы и получим:
#
# $A =
# \begin{pmatrix}
#   \sqrt{3} & \frac{\sqrt{3}}{2}\\
#   0 & \frac{5}{2}
# \end{pmatrix}
# \\
# A^{T} =
# \begin{pmatrix}
#   \sqrt{3} & 0\\
#   \frac{\sqrt{3}}{2} & \frac{5}{2}
# \end{pmatrix}
# \\
# \vec{b} =
# \begin{pmatrix}
#   \frac{3\sqrt{3}}{2} \\
#   \frac{5}{2}
# \end{pmatrix}$
#
# Вычислим:
#
# $
# \begin{pmatrix}
#   \xi_{st} \\
#   \eta_{st}
# \end{pmatrix} =
# \begin{pmatrix}
#   \sqrt{3} & \frac{\sqrt{3}}{2}\\
#   0 & \frac{5}{2}
# \end{pmatrix} ⋅
# \begin{pmatrix}
#   -1 \\
#   -1
# \end{pmatrix} +
# \begin{pmatrix}
#   \frac{3\sqrt{3}}{2} \\
#   \frac{5}{2}
# \end{pmatrix} =
# \begin{pmatrix}
#   -\frac{3\sqrt{3}}{2} \\
#   -\frac{5}{2}
# \end{pmatrix} +
# \begin{pmatrix}
#   \frac{3\sqrt{3}}{2} \\
#   \frac{5}{2}
# \end{pmatrix} =
# \begin{pmatrix}
#   0 \\
#   0
# \end{pmatrix}
# \\
# Σ_{st} = \frac{4}{75} ⋅
# \begin{pmatrix}
#   \sqrt{3} & \frac{\sqrt{3}}{2}\\
#   0 & \frac{5}{2}
# \end{pmatrix} \cdot
# \begin{pmatrix}
#   7 & -\frac{3}{2}\\
#   -\frac{3}{2} & 3
# \end{pmatrix} \cdot
# \begin{pmatrix}
#   \sqrt{3} & 0\\
#   \frac{\sqrt{3}}{2} & \frac{5}{2}
# \end{pmatrix} =
# \frac{4}{75} ⋅
# \begin{pmatrix}
#   \frac{25\sqrt{3}}{4} & 0\\
#   -\frac{15}{4} & \frac{15}{2}
# \end{pmatrix} ⋅
# \begin{pmatrix}
#   \sqrt{3} & 0\\
#   \frac{\sqrt{3}}{2} & \frac{5}{2}
# \end{pmatrix} = \\
# = \frac{4}{75} ⋅
# \begin{pmatrix}
#   \frac{75}{4} & 0\\
#   0 & \frac{75}{4}
# \end{pmatrix} =
# \begin{pmatrix}
#   1 & 0\\
#   0 & 1
# \end{pmatrix} = E
# $

# %% [markdown]
# ## Пункт 3
#
# Необходимо найти ортогональное преобразование, которое перевдет наш центрированный случайный вектор в вектор с независимыми компонентами. Для этого нам необходимо найти собственные числа матрицы $Σ^{-1}. Сделаем это с помощью кода на языке R

# %%
matrix <- matrix(c(3, 1.5, 1.5, 7), nrow = 2, ncol = 2)

eigen_result <- eigen(matrix)

eigenvalues <- eigen_result$values

print("Собственные числа:")
print(eigenvalues)
# Out:
# [1] "Собственные числа:"
# [1] 7.5 2.5

# %% [markdown]
# Итого мы получили собственные числа $λ_1 = 2.5, λ_2 = 7.5$
#
# Решив две системы уравнений мы получим 2 собственных вектора $\vec{v_1} = \begin{pmatrix}-3 \\ 1 \end{pmatrix} \cdot α, \vec{v_2} = \begin{pmatrix}1 \\ 3 \end{pmatrix} \cdot β$
# $\begin{Vmatrix}\vec{v_1}\end{Vmatrix} = \begin{Vmatrix}\vec{v_2}\end{Vmatrix} = \frac{1}{\sqrt{10}}
# $
#
# Из них составим матрицу ортогонального преобразования $Q$ и $Q^{-1}$:
#
# $Q = \frac{1}{\sqrt{10}} \cdot \begin{pmatrix}-3 & 1 \\ 1 & 3\end{pmatrix}$
#
# $Q^{-1} = \frac{1}{\sqrt{10}} \cdot \begin{pmatrix}-3 & 1 \\ 1 & 3\end{pmatrix}$
#
# Произведем вычисления:
# $Σ^{-1}_{new} = Q \cdot Σ^{-1} \cdot Q^{-1} =
# \begin{pmatrix}2.5 & 0\\ 0 & 7.5\end{pmatrix}$
#
# $Σ_{new} = \begin{pmatrix} \frac{2}{5} & 0 \\ 0 & \frac{2}{15}\end{pmatrix}$
#
# $\vec{μ'}=Q \cdot \vec{μ} = \frac{1}{\sqrt{10}}\begin{pmatrix} 2 \\ -4\end{pmatrix}$
#
# Таким образом, взяв коэффициенты из $Σ^{-1}_{new}$ получим следующую формулу для плотности:
#
# $𝛲'_{\xi,\eta}(x',y') = C' ⋅ \exp\left(-\frac{1}{2}\left(\begin{pmatrix} x' \\ y' \end{pmatrix} - \vec{μ'}\right)^{\intercal} \cdot Σ^{-1}_{new} \cdot \left(\begin{pmatrix} x' \\ y' \end{pmatrix} - \vec{μ'}\right)\right) = \\
# = C'\cdot exp \left(-\frac{1}{2} \left(2.5x^2-\sqrt{10}x+13+7.5y^2-6\sqrt{10}y\right)\right)$
#
# Вычислим $C'$:
#
# $C' = \frac{1}{2\pi \cdot \sqrt{|Σ_{new}|}} = \frac{1}{2\pi \cdot \sqrt{\frac{4}{75}}} = \frac{1}{2\pi \cdot \sqrt{\frac{4}{75}}} = \frac{5\sqrt{3}}{4\pi}$
# Итого получим:
# $𝛲'_{\xi,\eta}(x',y') = \frac{5\sqrt{3}}{4\pi} ⋅ \exp\left(-\frac{1}{2}\left(2.5x^2-\sqrt{10}x+13+7.5y^2-6\sqrt{10}y\right)\right)$
#
# Построим график плотности полученного распределения:

# %%
P_xi_eta <- function(x, y) {
  5 * sqrt(3) / (4 * pi) * exp(-0.5 * (2.5 * x^2 - sqrt(10) * x + 13 + 7.5 * y^2 - 6 * sqrt(10) * y))
}

x <- seq(-4, 4, length = 50)
y <- seq(-4, 4, length = 50)
z <- outer(x, y, P_xi_eta)

persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 0, phi = 0)
persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 90, phi = 90)
persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 45, phi = 45)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ##Пункт 4
# Необходимо вычислить характеристики совместного распределения случайного вектора $\left(-3\xi -5\eta, -\xi + \eta\right)^T$ и записать его плотность. Также надо построить график плотности полученного распределения.
#
# Пусть $\vec{t}=
# \begin{pmatrix}
#   -3\xi -5\eta \\
#   -\xi + \eta
# \end{pmatrix}
# = A \cdot
# \begin{pmatrix}
#   \xi \\
#   \eta
# \end{pmatrix},$\
# тогда $\vec{t} \sim \mathcal{N}(A \cdot \vec{\mu}, A \cdot \Sigma \cdot A^{\intercal})$, где матрица $A = \begin{pmatrix}
#   -3 & -5 \\
#   -1 & 1
# \end{pmatrix}$\
# Обозначим $A \cdot \vec{\mu} = \mathbb{E}[\vec{t}] = \vec{\mu}_{\vec{t}}$ и $A \cdot \Sigma \cdot A^{\intercal} = \Sigma_{\vec{t}}$\
# Произведем расчеты:

# %%
mu <- matrix(c(-1, -1), ncol = 1)
Sigma <- matrix(c(28/75, -2/25, -2/25, 4/25), nrow = 2)
A <- matrix(c(-3, -1, -5, 1), nrow = 2)

mu_t <- A %*% mu
Sigma_t <- A %*% Sigma %*% t(A)

det_Sigma_z <- (Sigma_z[1] * Sigma_z[4] - (Sigma_z[2] * Sigma_z[3]))

cat("mu_t:","\n")
prmatrix(mu_t)

cat("Sigma_t ⋅ 75/4:","\n")
prmatrix(Sigma_t * 75/4)

cat("det_Sigma_z ⋅ 75/4:", det_Sigma_z * 75/4)
# Out:
# mu_z:
#      [,1]
# [1,]    8
# [2,]    0
# Sigma_z ⋅ 75/4:
#      [,1] [,2]
# [1,]   93    3
# [2,]    3   13
# det_Sigma_z ⋅ 75/4: 64

# %% [markdown]
# $Σ_{\vec{t}} = \frac{4}{75} \cdot \begin{pmatrix}
#   93 & 3 \\
#   3 & 13
# \end{pmatrix} \\
# \vec{\mu}_\vec{t} =
# \begin{pmatrix}
#   8 \\
#   0
# \end{pmatrix} \\
# Σ_{\vec{t}}^{-1} = \frac{75}{256} \cdot \begin{pmatrix}
#   13 & -3 \\
#   -3 & 93
# \end{pmatrix}$
#
# Зная данные элементы восстановим функцию плотности:
# $𝛲_{\vec{t}}(\vec{t}) = \frac{8\sqrt{3}}{15\pi} ⋅ \exp\left(-\frac{1}{2} \cdot \frac{75}{256}\left[13\left(x - 8\right)^2 -6\left(x - 8\right)y + 93y^2\right]\right)$
#
# Построим график плотности полученного распределения:

# %%
P_z <- function(x, y) {
  8 * sqrt(3) / (15 * pi) * exp(-0.5 * (75/256) * (13 * (x - 8)^2 - 6 * (x - 8) * y + 93 * y^2))
}

x <- seq(0, 15, length = 50)
y <- seq(-7, 8, length = 50)
z <- outer(x, y, P_z)

persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 0, phi = 0)
persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 90, phi = 90)
persp(x, y, z, col = "lightblue", border = "black", ticktype = "detailed", theta = 45, phi = 45)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ##Пункт 5
#
# Найдем условное распределение $\xi$ при условии $\eta$.
# Для многомерного нормального распределения условное распределение также является нормальным. Условное распределение $\xi | \eta = y$ имеет следующую форму:\
# $\xi | \eta = y \sim \mathcal{N}(\mathbb{E}[\xi|\eta], \mathbb{D}[\xi|\eta])$, где\
# $\mathbb{E}[\xi|\eta] = \mu_{\xi} + \frac{\sigma_{\xi\eta}}{\sigma_{\eta}^2} \cdot (y - \mu_{\eta}),$\
# $\mathbb{D}[\xi|\eta] = \sigma_{\xi}^2 - \frac{\sigma_{\xi\eta}^2}{\sigma_{\eta}^2}.$\
# Вычислим $\mathbb{E}[\xi|\eta]$ и $\mathbb{D}[\xi|\eta]:$\
# $\mathbb{E}[\xi|\eta] = -1 + \frac{-\frac{2}{25}}{\frac{4}{25}} \cdot (\eta + 1) = -1 -\frac{1}{2} \cdot (\eta + 1) = -1 -\frac{1}{2} \cdot \eta -\frac{1}{2} = -\frac{3}{2} -\frac{1}{2} \cdot \eta;$\
# $\mathbb{D}[\xi|\eta] = \frac{28}{75} - \frac{(-\frac{2}{25})^2}{\frac{4}{25}} = \frac{28}{75} - \frac{\frac{4}{625}}{\frac{4}{25}} = \frac{28}{75} - \frac{1}{25} = \frac{25}{75} = \frac{1}{3}.$\
# Таким образом, условное распределение $\xi | \eta = y_{0}$ имеет вид:\
# $\xi | \eta = y_{0} \sim \mathcal{N}(-\frac{3}{2} -\frac{1}{2} \cdot \eta, \frac{1}{3}),$
# а функция плотности будет иметь вид:\
# $p_{\xi|\eta = y_{0}}(x) = \frac{1}{\sqrt{2\pi \sigma_{\xi|\eta}^2}}
# \exp\left( -\frac{(x - \mu_{\xi|\eta = y_{0}})^2}{2\sigma_{\xi|\eta}^2} \right);$\
# $p_{\xi|\eta = y_{0}}(x) = \frac{1}{\sqrt{2\pi \cdot \frac{1}{3}}} \exp\left( -\frac{\left( x - \left( -\frac{3}{2} - \frac{1}{2} \eta \right) \right)^2}{2 \cdot \frac{1}{3}} \right).$

# %% [markdown]
# ## Выводы
#
# В ходе выполнения работы были исследованы свойства данного двумерного случайного вектора, имеющего нормальное распределение. Для этого же вектора были вычислены основные числовые характеристики, а также произведены преобразования вектора в стандартный и в вектор с независимыми компонентами.  Был построен график плотности распределения данного вектора, а также график плотности для полученного в результате преобразований вектора с независимыми компонентами. Помимо этого, были вычислены характеристики совместного распределения случайного вектора и найдена его плотность распределения. Был построен график плотности совместного распределения случайного вектора. Было найдено условное распределение для данного вектора и были посчитаны условные математическое ожидание и дисперсия.\
# Наибольшеми сложностями в данной работе были поостроения графиков с использованием языка R и оформление текста работа с использованием Latex, что связанно с отсутсвием опыта работы с данными инструментами
