# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2363 Крюков Дмитрий Валерьевич. Вариант №6

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Нормальное распределение (одномерный случай):
#
# $ \xi \sim \mathcal{N}(a, \sigma^2) $
#
# $ p_\xi (x) = \cfrac{1}{\sigma\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{x-a}{\sigma}\right)^2\right) $
#
# Многомерное нормальное распределение:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ p_{\overrightarrow{\xi}} \left(\overrightarrow{x}\right) = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} \cdot \exp \left(-\cfrac{1}{2}\left(\overrightarrow{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overrightarrow{x}-\mu\right)\right) $
#
#
# Матрица ковариаций:
#
# $\Sigma = \begin{pmatrix}
# \mathbb{D}_\xi & \mathop{\mathrm{cov}}\nolimits(\xi, \eta)\\
# \mathop{\mathrm{cov}}\nolimits(\xi, \eta) & \mathbb{D}_\eta
# \end{pmatrix}$
#
# Математическое ожидание:
#
# $\mu = \mathbb E \vec{\xi} = (\mathbb E \xi1, ..., \mathbb E \xi_n)^{\intercal}$
#
#
# СКО:
#
# $\sigma_{ij} = \mathop{cov}(\xi_i, \xi_j)$
#
# Преобразование характеристик:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ \overrightarrow{\eta} = A \overrightarrow{\xi} + \overrightarrow{b} $
#
# $ \overrightarrow{\eta} \sim \mathcal{N}(A \overrightarrow{\mu} + \overrightarrow{b}, A \Sigma A^{\intercal}) $
#
# Условное распределение для абсолютно непрерывных величин:
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}  (x, y_0)}{p_\eta  (y_0)} $
#
# Стандартное нормально распределение - нормальное распределение с нулевым мат. ожиданием и единичной дисперсией. В многомерном случае - нулевой вектор мат. ожидания и единичная ковариационная матрица.
#
# Центрированный случайный вектор - случайный вектор с нулевым мат. ожиданием.
#
#
# Аффинное преобразование - преобразование вида:
#
# $ \begin{pmatrix}
# x\\
# y
# \end{pmatrix} = A \begin{pmatrix}
# u\\
# v
# \end{pmatrix} + \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} $

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
#
# Плотность двумерного нормального распределения имеет вид:
# $p_{\xi,\eta}(x, y) = C \cdot \exp\left(-\frac{1}{2} \cdot (4x^2 + 4xy + 7y^2 - 12x + 6y + 15)\right);$
#
# ###1. Вычислим вектор математических ождианий и ковариационные характеристики данного случайного вектора. Для начала приведем квадратичную форму $Q(x, y)$ к каноническому виду:
# $Q(x, y) = 4x^2 - 9xy + 16y^2 + 7x + 14y + 14 =$\
# $= 4x^2-9xy + \frac{81}{16}y^2 + 7x + 14y + 14 + \frac{175}{16}y^2 =$\
# $= 4(x^2 - \frac{9}{4}xy + (\frac{9}{8}y)^2) + 7x - \frac{63}{8}y + 14 + \frac{175}{16}y^2 + \frac{175}{8}y =$\
# $= 4(x - \frac{9}{8}y)^2 + 7(x - \frac{9}{8}y) + 14 + \frac{175}{16}y^2 + \frac{175}{8}y =$\
# $= 4((x - \frac{9}{8}y)^2 + \frac{7}{4}(x - \frac{9}{8}y)) + \frac{49}{16} + \frac{175}{16}(y+1)^2 =$\
# $= 4((x - \frac{9}{8}y)^2 + 2(x - \frac{9}{8}y)\frac{7}{8} + (\frac{7}{8})^2) + \frac{175}{16}(y+1)^2 =$\
# $=(*) 4((x - \frac{9}{8}y) + \frac{7}{8} )^2 + \frac{175}{16}(y+1)^2 (*)=$\
# $= 4( (x+2) - \frac{9}{8}(y + 1))^2 + \frac{175}{16}(y + 1)^2 =$\
# $= 4( (x+2)^2  - \frac{9}{4}(x + 2)(y + 1) + \frac{81}{64} (y + 1)^2) + \frac{175}{16}(y+1)^2 =$\
# $= 4(x + 2)^2  - 9(x + 2)(y + 1) + \frac{81}{16} (y + 1)^2 + \frac{175}{16}(y+1)^2 =$\
# $= 4(x + 2)^2  - 9(x + 2)(y + 1) + 16(y + 1)^2 $\
# Получаем:\
# $p_{\xi,\eta}(x, y) = C \cdot \exp\left(-\frac{1}{2} \cdot \left[4(x + 2)^2  - 9(x + 2)(y + 1) + 16(y + 1)^2\right]\right).$\
# Вектор математических ожиданий данного случайного вектора имеет вид:\
# $\mathbb{E}\begin{pmatrix} \xi \\ \eta \end{pmatrix} = \begin{pmatrix} -2 \\ -1 \end{pmatrix}.$\
# Получим матрицу $\Sigma^{-1}:$\
# $\Sigma^{-1} = \begin{pmatrix} 4 & -4.5 \\ -4.5 & 16 \end{pmatrix}.$\
# Найдем ковариационную матрицу $\Sigma:$\
# $\Sigma = \frac{1}{|\Sigma^{-1}|} \cdot \begin{pmatrix} 16 & 4.5 \\ 4.5 & 4 \end{pmatrix} = \frac{1}{43.75} \cdot \begin{pmatrix} 16 & 4.5 \\ 4.5 & 4 \end{pmatrix}$
#
# Ковариционная матрица имеет вид: $\Sigma = \begin{pmatrix} \mathbb{D}\xi & \mathop{\mathrm{cov}}\limits(\xi, \eta) \\ \mathop{\mathrm{cov}}\limits(\eta, \xi) & \mathbb{D}\eta \end{pmatrix},$ следовательно запишем ковариационные характеристики:\
# $\mathbb{D}\xi = \frac{1}{43.75} \cdot 16 = \frac{16}{43.75};$\
# $\mathbb{D}\eta = \frac{1}{43.75} \cdot 4 = \frac{4}{43.75};$\
# $\mathop{\mathrm{cov}}\limits(\xi, \eta) = \mathop{\mathrm{cov}}\limits(\eta, \xi) = \frac{1}{43.75} \cdot 4.5 = \frac{4.5}{43.75};$\
# ${\mathop{\mathrm{\rho}}\limits(\xi, \eta)} = \frac{\mathop{\mathrm{cov}}\limits(\xi, \eta)}{\sqrt{\mathbb{D}\xi\cdot\mathbb{D}\eta}} = \frac{ \frac{4.5}{43.75}}{\sqrt{\frac{16}{43.75} \cdot \frac{4}{43.75}}} = 0.5625;$\
# $C = \frac{1}{2\pi \cdot \sqrt{|\Sigma|}} = \frac{1}{2\pi \cdot \sqrt{\frac{1}{43.75}}} = \frac{5\sqrt{7}}{4\pi}.$\
# Построим график плотности распределения $p_{\xi,\eta}:$

# %%
#Импортируем все нужные библиотеки
import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import multivariate_normal
from math import sqrt

# %%
mu = np.array([[-2], [-1]])
Sigma = np.array([[16 / 43.75, 4.5 / 43.75],
                  [4.5 / 43.75, 4 / 43.75]])

def p_xi_eta(x, y):
    return ((5 * np.sqrt(7)) / (4 * np.pi)) * np.exp(-0.5 * (4 * (x + 2)**2 - 9 * (x + 2) * (y + 1) + 16 * (y + 1)**2))

x = np.linspace(-3, 3, 50)
y = np.linspace(-3, 3, 50)
X, Y = np.meshgrid(x, y)

z_1 = p_xi_eta(X, Y)
z_2 = multivariate_normal.pdf(np.c_[X.ravel(), Y.ravel()], mean=mu.ravel(), cov=Sigma).reshape(X.shape)

fig = plt.figure(figsize=(25, 8))

ax1 = fig.add_subplot(121, projection='3d')
ax1.plot_surface(X, Y, z_1, cmap='viridis', edgecolor='black')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Плотность распределения')
ax1.set_title('Плотность распределения, представленная графически с помощью функции плотности')

ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_surface(X, Y, z_2, cmap='viridis', edgecolor='black')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')


ax2.set_zlabel('Плотность распределения', labelpad=10)

ax2.set_title('Графическое представление многомерного распределения,\n построенное по ковариационной матрице и вектору математических ожиданий')


plt.show()

# %% [markdown]
# ###2. Найдем аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный:
# Для начала снова преобразуем выражение $(*) 4((x - \frac{9}{8}y) + \frac{7}{8} )^2 + \frac{175}{16}(y+1)^2 (*):$\
# $(2x - \frac{9}{4}y + \frac{7}{4} )^2 + (\frac{5 \sqrt7}{4}y + \frac{5 \sqrt7}{4})^2 $
#
# Афинное преобразование осуществляется по следующим формулам:\
# $\vec{\xi} \sim \mathcal{N}(\vec{\mu}, \Sigma)$ — исходный случайный вектор;\
# $\vec{\xi}_{st} \sim \mathcal{N}(\vec{\mu}_{st}, \Sigma_{st})$ — стандартный нормальный случайный вектор;\
# $\vec{\xi}_{st} = A \cdot \vec{\xi} + b$ — афинное преобразование случайного вектора;\
# $\vec{\mu}_{st} = A \cdot \vec{\mu} + b$ — получение стандартного нормального вектора математических ожиданий из исходного;\
# $\Sigma_{st} = A \cdot \Sigma \cdot A^{\intercal}$ — получение стандартной нормальной ковариационной матрицы из исходной.\
# Исходя из упрощенного выражения, матрица $A$ имеет вид:\
# $A = \begin{pmatrix} 2 & -\frac{9}{4} \\ 0 & \frac{5 \sqrt7}{4} \end{pmatrix},$\
# матрица $b:$\
# $b = \begin{pmatrix} \frac{7}{4} \\ \frac{5 \sqrt7}{4} \end{pmatrix},$\
# а вектор $\vec{\mu}:$\
# $\vec{\mu} = \mathbb{E}\begin{pmatrix} \xi \\ \eta \end{pmatrix} = \begin{pmatrix} -2 \\ -1 \end{pmatrix}.$\
# Значит $\vec{\mu}_{st} = \mathbb{E}\begin{pmatrix} \xi_{st} \\ \eta_{st} \end{pmatrix} = \begin{pmatrix} 2 & -\frac{9}{4} \\ 0 & \frac{5 \sqrt7}{4} \end{pmatrix} \cdot \begin{pmatrix} -2 \\ -1 \end{pmatrix} + \begin{pmatrix} \frac{7}{4} \\ \frac{5 \sqrt7}{4}  \end{pmatrix} =\begin{pmatrix} -\frac{7}{4} \\ -\frac{5 \sqrt7}{4}  \end{pmatrix} + \begin{pmatrix} \frac{7}{4} \\ \frac{5 \sqrt7}{4}  \end{pmatrix} = \begin{pmatrix} 0 \\ 0  \end{pmatrix},$\
# а $\Sigma_{st} = \frac{1}{43.75} \cdot \begin{pmatrix} 2 & -\frac{9}{4} \\ 0 & \frac{5 \sqrt7}{4} \end{pmatrix} \cdot \begin{pmatrix} 16 & 4.5 \\ 4.5 & 4 \end{pmatrix} \cdot \begin{pmatrix} 2 & -\frac{9}{4} \\ 0 & \frac{5 \sqrt7}{4} \end{pmatrix}^{\intercal} = \frac{1}{43.75} \cdot \begin{pmatrix} \frac{175}{8} & 0 \\ \frac{45 \sqrt7}{8} & 5 \sqrt7 \end{pmatrix} \cdot \begin{pmatrix} 2 & -\frac{9}{4} \\ 0 & \frac{5 \sqrt7}{4} \end{pmatrix}^{\intercal} =$\
# $= \frac{1}{43.75} \cdot \begin{pmatrix} 43.75 & 0 \\ 0 & 43.75 \end{pmatrix}=
# \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}.$

# %% [markdown]
# В результате произведенных вычислений получаем стандартный нормальный вектор математических ожиданий $\vec{\mu}_{st}$
# и стандартную нормальную ковариационную матрицу $\Sigma_{st}:$\
# $\vec{\mu}_{st} = \begin{pmatrix} 0 \\ 0 \end{pmatrix};$\
# $\Sigma_{st} = \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}.$\
# Стандартный нормальный случайный вектор имеет вид:\
# $\vec{\xi}_{st} \sim \mathcal{N}\left(\begin{pmatrix} 0 \\ 0 \end{pmatrix},  \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix}\right).$
# ###3. Найдем ортогональное преобразование, переводящее соответствующий центрированный вектор в вектор с независимыми компонентами.
# Найдем собственные числа и собственные вектора для матрицы $\Sigma^{-1},$ для этого решим уравнение:\
# $\mathop{\mathrm{det}}(\Sigma^{-1} - \lambda \cdot E) = 0$\
# $\left|\begin{pmatrix} 4 & -4.5 \\ -4.5 & 16 \end{pmatrix} - \begin{pmatrix} \lambda & 0 \\ 0 & \lambda \end{pmatrix}\right| = \left| \begin{pmatrix} 4 - \lambda & -4.5 \\ -4.5 & 16 - \lambda\end{pmatrix} \right| = 0$\
# $(4 - \lambda)(16 - \lambda) - 20.25 = 0$\
# $64 - 4x - 16x + x^2 - 20.25 = 0$\
# $x^2 - 20x + 43.75 = 0$\
# $x^2 - 20x + \frac{175}{4} = 0$\
# $4x^2 - 80x + 175 = 0$\
# $4x^2 - 10x - 70x + 175 = 0$\
# $2x(2x - 5) - 35(2x - 5) = 0$\
# $(2x - 5)(2x - 35) = 0$\
# Получили собственные числа:\
# $\lambda_{1} = \frac{5}{2}; \lambda_{2} = \frac{35}{2}$

# %% [markdown]
# Решим системы уравнений для $\lambda_{1}$ и $\lambda_{2}:$\
# 1) Для $\lambda_{1}:$\
# $\begin{equation*}
#  \begin{cases}
#    \frac{3}{2} \cdot u_1 - 4.5 \cdot v_1 = 0
#    \\
#    -4.5 \cdot u_1 + \frac{27}{2} \cdot v_1 = 0
#  \end{cases}
# \end{equation*}$\
# $\begin{equation*}
#  \begin{cases}
#    u_1 =  3u_1
#    \\
#    -\frac{9}{2} \cdot u_1 + \frac{27}{2} \cdot v_1 = 0
#  \end{cases}
# \end{equation*}$\
# $\begin{equation*}
#  \begin{cases}
#    u_1 =  3 \alpha
#    \\
#    \sqsupset \alpha \in \mathbb{R}
#  \end{cases}
# \end{equation*}$\
# $\vec{u_1} = \begin{pmatrix} 3 \\ 1 \end{pmatrix} \cdot \alpha, \alpha \in \mathbb{R}$\
# $|\vec{u_1}| = \sqrt{9 + 1} = \sqrt{10}$\
# $\vec{u_1} = \begin{pmatrix} 3 \\ 1 \end{pmatrix} \cdot \frac{1}{\sqrt{10}}$\
# 2) Для $\lambda_{2}:$\
# $\begin{equation*}
#  \begin{cases}
#    \frac{-27}{2} \cdot u_2 - 4.5 \cdot v_2 = 0
#    \\
#    -4.5 \cdot u_2 - \frac{3}{2} \cdot v_2 = 0
#  \end{cases}
# \end{equation*}$\
# $\begin{equation*}
#  \begin{cases}
#    v_2 = - 3 \cdot u_2
#    \\
#    -\frac{9}{2} \cdot u_2 - \frac{3}{2} \cdot v_2 = 0
#  \end{cases}
# \end{equation*}$\
# $\begin{equation*}
#  \begin{cases}
#    v_2 = - 3 \cdot \beta
#    \\
#    \sqsupset \beta \in \mathbb{R}
#  \end{cases}
# \end{equation*}$\
# $\vec{v_2} = \begin{pmatrix} 1 \\ -3 \end{pmatrix} \cdot \beta, \beta \in \mathbb{R}$\
# $|\vec{v_2}| = \sqrt{1 + 9} = \sqrt{10}$\
# $\vec{v_2} = \begin{pmatrix} 1 \\ -3 \end{pmatrix} \cdot \frac{1}{\sqrt{10}}$\
# Составим матрицу $Q^{\intercal}$ из собственных векторов:\
# $Q^{\intercal} = \begin{pmatrix} 1 & 3 \\ -3 & 1  \end{pmatrix} \cdot \frac{1}{\sqrt{10}},$ тогда матрица $Q$ будет иметь вид:\
# $Q = \begin{pmatrix} 1 & -3 \\ 3 & 1 \end{pmatrix} \cdot \frac{1}{\sqrt{10}}.$\
# Произведем проверку:\
# При вычислении выражения $Q \cdot \Sigma \cdot Q^{\intercal}$ должна получится диагональная матрица;$\
# \ \frac{1}{\sqrt{10} \cdot 43.75 \cdot \sqrt{10}} \cdot \begin{pmatrix} 1 & -3 \\ 3 & 1 \end{pmatrix} \cdot \begin{pmatrix} 16 & 4.5 \\ 4.5 & 4 \end{pmatrix} \cdot \begin{pmatrix} 1 & 3 \\ -3 & 1 \end{pmatrix} = \begin{pmatrix} \frac{2}{35} & 0 \\ 0 & \frac{2}{5} \end{pmatrix}$\
# Поскольку результат удовлетворяет условию, можно сделать вывод, что преобразование было выполнено корректно.\
# Так как полученная матрица $D = \begin{pmatrix} \frac{2}{35} & 0 \\ 0 & \frac{2}{5} \end{pmatrix}$ является диагональной матрицей из собственных значений $\Sigma^{-1},$\
# $\Sigma = Q \cdot D^{-1} \cdot Q^{\intercal},$\
# где: $D^{-1} = \frac{1}{|D|} \cdot \begin{pmatrix} \frac{2}{35} & 0 \\ 0 & \frac{2}{5}  \end{pmatrix} = \frac{4}{175} \cdot \begin{pmatrix} \frac{2}{35} & 0 \\ 0 & \frac{2}{5} \end{pmatrix} = \begin{pmatrix} \frac{5}{2} & 0 \\ 0 & \frac{35}{2} \end{pmatrix}.$\
# $\vec{\mu}' = Q \cdot \vec{\mu} = \frac{1}{\sqrt{10}} \cdot  \begin{pmatrix} 1 & -3 \\ 3 & 1 \end{pmatrix}  \cdot \begin{pmatrix} -2 \\ -1 \end{pmatrix} = \begin{pmatrix} \frac{1}{\sqrt{10}} \\ -\frac{7}{\sqrt{10}} \end{pmatrix}$\
# Таким образом, плотность распределения независимых компонентов центрированного вектора будет иметь вид:\
# $p_{\xi,\eta}(x', y') = \frac{1}{2\pi \cdot \sqrt{\begin{vmatrix} D \end{vmatrix}}} \cdot \exp\left(-\frac{1}{2} \cdot \left[  \begin{pmatrix} x' \\ y' \end{pmatrix} - \vec{\mu}' \right]^{\intercal} \cdot D^{-1} \cdot \left[  \begin{pmatrix} x' \\ y' \end{pmatrix} - \vec{\mu}' \right] \right) =$\
# $= \frac{1}{2\pi \cdot \sqrt{\frac{4}{175}}} \cdot \exp\left(-\frac{1}{2} \cdot \left[  \begin{pmatrix} x' \\ y' \end{pmatrix} - \begin{pmatrix} \frac{1}{\sqrt{10}} \\ -\frac{7}{\sqrt{10}} \end{pmatrix} \right]^{\intercal} \cdot \begin{pmatrix} \frac{5}{2} & 0 \\ 0 & \frac{35}{2} \end{pmatrix} \cdot \left[  \begin{pmatrix} x' \\ y' \end{pmatrix} - \begin{pmatrix} \frac{1}{\sqrt{10}} \\ -\frac{7}{\sqrt{10}} \end{pmatrix}\right] \right) =$
# $= \frac{5\sqrt{7}}{4\pi}\cdot \exp\left(-\frac{1}{2} \cdot \left[ \frac{5}{2}x'^{2} + \frac{35}{2}y'^{2} - \frac{\sqrt{10}}{2}x + \frac{49\sqrt{10}}{2}y + 86 \right] \right)$\
# $p_{\xi,\eta}(x', y') = \frac{5\sqrt{7}}{4\pi}\cdot \exp\left(-\frac{1}{2} \cdot \left[ \frac{5}{2}x'^{2} + \frac{35}{2}y'^{2} - \frac{\sqrt{10}}{2}x + \frac{49\sqrt{10}}{2}y + 86 \right] \right).$\
# Построим график плотности полученного распределения:

# %%
def p_xi_eta(x, y):
  return ((5 * np.sqrt(7)) / (4 * np.pi)) * np.exp(-0.5 * (2.5 * x**2 + 17.5 * y**2 - sqrt(10)/2 * x + (49 * sqrt(10)) / 2 *y))

x = np.linspace(-3, 3, 50)
y = np.linspace(-3, 3, 50)

X, Y = np.meshgrid(x, y)
Z = p_xi_eta(X, Y)

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(X, Y, Z, cmap='Blues', edgecolor='black', shade=False)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Плотность распределения')
ax.set_title('График плотности распределения\nнезависимых компонентов центрированного вектора')

plt.show()

# %% [markdown]
# ###4. Вычислим характеристики совместного распределения случайного вектора $(-\xi - 5\eta, -\xi + 4\eta)^{\intercal}$ и записать его плотность.
#
# $ \sqsupset \vec{z}=\begin{pmatrix}-\xi - 5\eta \\ -\xi + 4\eta \end{pmatrix} = A \cdot \begin{pmatrix} \xi \\ \eta \end{pmatrix},$\
# тогда $\vec{z} \sim \mathcal{N}(A \cdot \vec{\mu}, A \cdot \Sigma \cdot A^{\intercal})$, где матрица $A = \begin{pmatrix} -1 & -5 \\ -1 & 4 \end{pmatrix}$\
# Обозначим $A \cdot \vec{\mu} = \mathbb{E}[\vec{z}] = \vec{\mu}_{\vec{z}}$ и $A \cdot \Sigma \cdot A^{\intercal} = \Sigma_{\vec{z}}$\
# $\vec{\mu}_{\vec{z}} = \begin{pmatrix} -1 & -5 \\ -1 & 4 \end{pmatrix} \cdot \begin{pmatrix} -2 \\ -1 \end{pmatrix} = \begin{pmatrix} 7 \\ -2 \end{pmatrix},$\
# $\Sigma_{\vec{z}} = \frac{1}{43.75} \cdot \begin{pmatrix} -1 & -5 \\ -1 & 4 \end{pmatrix} \cdot \begin{pmatrix} 16 & 4.5 \\ 4.5 & 4 \end{pmatrix} \cdot \begin{pmatrix} -1 & -1 \\ -5 & 4 \end{pmatrix} = \frac{1}{43.75} \cdot \begin{pmatrix} 161 & -59.5 \\ -59.5 & 44 \end{pmatrix}.$\
# Имея ковариационную матрицу, можем выписать харктеристики совместного распределения:\
# $\mathbb{D}[-\xi - 5\eta] = \frac{1}{43.75} \cdot 161 = \frac{161}{43.75}=3.68;$\
# $\mathbb{D}[-\xi + 4\eta] = \frac{1}{43.75} \cdot 44 = \frac{44}{43.75} ;$\
# $\mathop{\mathrm{cov}}\limits(-\xi - 5\eta, -\xi + 4\eta) = \frac{1}{43.75} \cdot (-59.5) = -\frac{59.5}{43.75} = -1.36;$\
# ${\mathop{\mathrm{\rho}}\limits(\xi, \eta)} = \frac{\mathop{\mathrm{cov}}\limits(-\xi - 5\eta, -\xi + 4\eta)}{\sqrt{\mathbb{D}[-\xi + 2\eta] \cdot \mathbb{D}[-2\xi - \eta]}} = -\frac{1.36}{\sqrt{\frac{44}{43.75} \cdot 3.68}} = \frac{17 \cdot \sqrt{1771}}{1012};$\
# Теперь можем найти функцию плотности:\
# $p_{\vec{z}}(\vec{z}) = \frac{1}{2\pi \cdot \sqrt{|\Sigma_{\vec{z}}|}} \cdot \exp\left( -\frac{1}{2} \cdot (\vec{z} - \vec{\mu}_{\vec{z}})^{\intercal} \cdot \Sigma_{\vec{z}}^{-1} \cdot (\vec{z} - \vec{\mu}_{\vec{z}}) \right);$\
# $\Sigma_{\vec{z}}^{-1} = \frac{1}{|\Sigma_{\vec{z}}|} \cdot \begin{pmatrix} 44 & 59.5 \\ 59.5 & 161 \end{pmatrix} = \frac{43.75}{3543.75} \cdot \begin{pmatrix} 44 & 59.5 \\ 59.5 & 161 \end{pmatrix};$\
# $p_{\vec{z}}(\vec{z}) = \frac{1}{2\pi \cdot \sqrt{\frac{3543.75}{43.75}}} \cdot \exp\left( -\frac{1}{2} \cdot \frac{43.75}{3543.75} \cdot \left[ \begin{pmatrix} -x - 5y \\ -x + 4y \end{pmatrix} - \begin{pmatrix} 7 \\ -2 \end{pmatrix} \right]^{\intercal} \cdot \begin{pmatrix} 44 & 59.5 \\ 59.5 & 161 \end{pmatrix} \cdot \left[ \begin{pmatrix} -x - 5y \\ -x + 4y \end{pmatrix} - \begin{pmatrix} 7 \\ -2 \end{pmatrix} \right] \right)=$\
# $= \frac{1}{2\pi \cdot \sqrt{\frac{3543.75}{43.75}}} \cdot \exp\left( -\frac{1}{2} \cdot \frac{43.75}{3543.75} \cdot \begin{pmatrix} -x - 5y - 7 & -x + 4y + 2 \end{pmatrix} \cdot \begin{pmatrix} 44 & 59.5 \\ 59.5 & 161 \end{pmatrix} \cdot \begin{pmatrix} -x - 5y -7  \\ -x + 4y + 2 \end{pmatrix} \right)=$\
# $= \frac{1}{2\pi \cdot \sqrt{\frac{3543.75}{43.75}}} \cdot \exp\left( -\frac{1}{2} \cdot \frac{43.75}{3543.75} \cdot \begin{pmatrix} -103.5x + 18y - 189 & -220.5x + 346.5y - 94.5 \end{pmatrix} \cdot \begin{pmatrix} -x - 5y- 7 \\ -x + 4y + 2 \end{pmatrix} \right)=$
# $= \frac{1}{2\pi \cdot \sqrt{\frac{3543.75}{43.75}}} \cdot \exp\left( -\frac{1}{2} \cdot \frac{43.75}{3543.75} \cdot \left[324x^2 + 567x + 1296y^2 + 1134y - 729xy + 1134\right] \right);$
# $p_{\vec{z}}(\vec{z}) = \frac{1}{2\pi \cdot 9} \cdot \exp\left( -\frac{1}{2} \cdot \left[4x^2 + 7x + 16y^2 + 14y - 9xy + 14\right] \right)$\
# Построим график плотности полученного совместного распределения:

# %%
def p_z(xi, eta):
    return (1 / (2 * np.pi * 9)) * np.exp(-0.5 * ((4 * xi**2) + (7 * xi) + (16 * eta**2) + (14 * eta) - (9 * xi * eta) + 14))

xi = np.linspace(-3, 3, 50)
eta = np.linspace(-3, 3, 50)

X, Y = np.meshgrid(xi, eta)
Z = p_z(X, Y)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='white')

ax.set_xlabel('xi')
ax.set_ylabel('eta')
ax.set_zlabel('Плотность распределения')
ax.set_title('График плотности\nсовместного распределения p_z')

plt.show()

# %% [markdown]
# ###5. Найдем условное распределение $\xi$ при условии $\eta$.
# Для многомерного нормального распределения условное распределение также является нормальным. Условное распределение $\xi | \eta = y$ имеет форму:\
# $\xi | \eta = y \sim \mathcal{N}(\mathbb{E}[\xi|\eta], \mathbb{D}[\xi|\eta])$, где\
# $\mathbb{E}[\xi|\eta] = \mu_{\xi} + \frac{\sigma_{\xi\eta}}{\sigma_{\eta}^2} \cdot (y - \mu_{\eta}),$\
# $\mathbb{D}[\xi|\eta] = \sigma_{\xi}^2 - \frac{\sigma_{\xi\eta}^2}{\sigma_{\eta}^2}.$\
# Вычислим $\mathbb{E}(\xi|\eta)$ и $\mathbb{D}(\xi|\eta).$\
# $\mathbb{E}[\xi|\eta] = -2 + \frac{\frac{4.5}{43.75}}{\frac{4}{43.75}} \cdot (\eta + 1) = -0.875 + 1.125\eta,$\
# $\mathbb{D}[\xi|\eta] = \frac{16}{43.75} - \frac{(\frac{4.5}{43.75})^2}{\frac{4}{43.75}} = \frac{1}{4}$\
# Таким образом, условное распределение $\xi | \eta =\eta$ имеет вид:\
# $\xi | \eta = y \sim \mathcal{N}(-0.875 + 1.125\eta, \frac{1}{4})$,\
# функция плотности будет иметь вид:\
# $p_{\xi|\eta = y}(x) = \frac{1}{\sqrt{2\pi \sigma_{\xi|\eta}^2}}
# \exp\left( -\frac{(x - \mathbb{E}[\xi|\eta])^2}{2 \cdot \sigma_{\xi|\eta}^2} \right);$\
# $p_{\xi|\eta=y}(x) = \frac{1}{\sqrt{2\pi \cdot \frac{1}{4}}} exp(-\frac{(x - (-0.875 + 1.125\eta))^2}{2 \cdot \frac{1}{4} }).$

# %% [markdown]
# ## Выводы
#
# В ходе работы были исследованы свойства двумерного случайного вектора с нормальным распределением. Были получены следующие результаты:
#
# • Вектор математических ожиданий и ковариационные характеристики исходного случайного вектора были определены путем приведения квадратичной формы к каноническому виду.\
# • Найдено аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.\
# • Найдено ортогональное преобразование, переводящее соответствующий центрированный вектор в вектор с независимыми компонентами.\
# • Вычислены характеристики совместного распределения случайного вектора.\
# • Найдено условное распределение.
#
# Данное исследование позволило овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами, а также углубить понимание свойств двумерных случайных векторов с нормальным распределением.
#
# В процессе реализации проекта я столкнулся с определенными трудностями, связанными с оформлением документации в LaTeX, что было обусловлено недостаточным опытом работы с этим инструментом. Дополнительные сложности возникли при приведении вектора к каноническому виду, поскольку исходные коэффициенты представляли собой не самые удобные для проведения вычислений.
