# %% [markdown]
# ###### Практическая работа №1: Название работы
#
# Выполнил студент гр. 2363 Хлиповко Виктор Александрович. Вариант №18

# %% [markdown]
# ## Цель работы
#
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Основные теоретические положения
#
# Нормальное распределение (одномерный случай):
#
# $ \xi \sim \mathcal{N}(a, \sigma^2) $
#
# $ p_\xi (x) = \cfrac{1}{\sigma\sqrt{2\pi}} \cdot \exp \left(-\cfrac{1}{2}\left(\cfrac{x-a}{\sigma}\right)^2\right) $
#
# Многомерное нормальное распределение:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ p_{\overrightarrow{\xi}} \left(\overrightarrow{x}\right) = \cfrac{1}{\left(2\pi\right)^{n/2} \sqrt{\det\Sigma}} \cdot \exp \left(-\cfrac{1}{2}\left(\overrightarrow{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overrightarrow{x}-\mu\right)\right) $
#
# Математическое ожидание:
#
# $\mu = \mathbb E \vec{\xi} = (\mathbb E \xi1, ..., \mathbb E \xi_n)^{\intercal}$
#
# Матрица ковариаций:
#
# $\Sigma = \begin{pmatrix}
# \mathbb{D}_\xi & \mathop{\mathrm{cov}}\nolimits(\xi, \eta)\\
# \mathop{\mathrm{cov}}\nolimits(\xi, \eta) & \mathbb{D}_\eta
# \end{pmatrix}$
#
# СКО:
#
# $\sigma_{ij} = \mathop{cov}(\xi_i, \xi_j)$
#
# Преобразование характеристик:
#
# $ \overrightarrow{\xi} \sim \mathcal{N}(\overrightarrow{\mu}, \Sigma) $
#
# $ \overrightarrow{\eta} = A \overrightarrow{\xi} + \overrightarrow{b} $
#
# $ \overrightarrow{\eta} \sim \mathcal{N}(A \overrightarrow{\mu} + \overrightarrow{b}, A \Sigma A^{\intercal}) $
#
# Условное распределение для абсолютно непрерывных величин:
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}  (x, y_0)}{p_\eta  (y_0)} $
#
# Стандартное нормально распределение - нормальное распределение с нулевым мат. ожиданием и единичной дисперсией. В многомерном случае - нулевой вектор мат. ожидания и единичная ковариационная матрица.
#
# Центрированный случайный вектор - случайный вектор с нулевым мат. ожиданием.
#
# Аффинное преобразование - преобразование вида:
#
# $ \begin{pmatrix}
# x\\
# y
# \end{pmatrix} = A \begin{pmatrix}
# u\\
# v
# \end{pmatrix} + \begin{pmatrix}
# \alpha\\
# \beta
# \end{pmatrix} $

# %% [markdown]
# ## Постановка задачи
#
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Выполнение работы
#
# Плотность двумерного нормального распредления имеет вид:
#
# $P_{\xi, \eta}(x, y) = C \cdot \exp\left(-\frac{1}{2}\left(3x^2-3xy+7y^2+11y+3x+7\right)\right)$
#
# ### Задание 1
# Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построитьь график плотности распределния $P_{\xi, \eta}$
#
# $q(x, y) = 3x^2 - 3xy + 7y^2 + 3x + 11y + 7 = 3\left(x^2 + x\right) - 3xy + 7\left(y^2 + y\right) + 4y + 7 =$
# $= 3\left(x^2 + 2x + 1\right) - 3xy - 3x + 7\left(y^2 + 2y + 1\right) - 3y - 3 =$
# $= 3(x + 1)^2 + 7(y + 1)^2 - 3xy - 3x - 3y -3 = 3(x + 1)^2 - 3(x+1)(y+1) + 7(y + 1)^2$
#
# Тогда обратная ковариационная матрица будет иметь вид:
#
# $\Sigma^{-1} = \begin{pmatrix}
# 3 & -1.5\\
# -1.5 & 7
# \end{pmatrix}$
#
# Тогда сама ковариационная матрица будет равна следующему:
#
# $\Sigma = \cfrac{4}{75}\begin{pmatrix}
# 7 & 1.5\\
# 1.5 & 3
# \end{pmatrix}$
#
# При этом детерминант будет равен $|\Sigma| = \cfrac{4}{75}$
#
# Вектор математических ожиданий будет иметь вид:
#
# $\mathbb{E}\begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} = \begin{pmatrix}
# -1\\
# -1
# \end{pmatrix}$
#
# Дисперсия по $\xi$ и $\eta$
#
# $\mathbb{D}_\xi = \cfrac{28}{75}, \quad \mathbb{D}_\eta = \cfrac{4}{25}$
#
# Коэффициент ковариации равен $\mathop{\mathrm{cov}}\nolimits(\xi, \eta) = \cfrac{2}{25}$
#
# Коэффициент корреляции равен $\rho_{\xi, \eta} = \cfrac{3\sqrt{21}}{28}$
#
# Коэффициент C равен $C = \cfrac{1}{(2\pi)^{\cfrac{n}{2}}\sqrt{det \Sigma}} = \cfrac{5\sqrt{3}}{4\pi}$

# %% [markdown]
# ### График плотности распределения

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Определяем область значений для x и y
x = np.linspace(-4, 2, 50)
y = np.linspace(-4, 3, 50)

# Создаем сетку координат
X, Y = np.meshgrid(x, y)

# Вычисляем значения функции
Z = (5*np.sqrt(3)/(2*np.pi))*np.exp(-1/2*(3*X**2 - 3*X*Y + 7*Y**2 + 11*Y + 3*X + 7))

# Создаем 3D-график
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.viridis)

# Настраиваем оси
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('P(x, y)')

# Отображаем график
#ax.set(title="")
plt.show()

# %% [markdown]
# ### Задание 2
# Найти аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный.
#
# $q(x,  y) = 3x^2 - 3xy + 7y^2 + 11y + 3x + 7 = 4\cfrac{3}{4}x^2 - 4\cfrac{3}{4}xy + 4\cfrac{3}{4}x +
# \cfrac{3}{4}y^2 - \cfrac{6}{4}y + \cfrac{3}{4} + \cfrac{25}{4}y^2 + \cfrac{50}{4}y + \cfrac{25}{4} =$
# $= \cfrac{3}{4}\left(4x^2 - 2xy + 2x - 2xy + y^2 - y + 2x - y + 1\right) + \cfrac{25}{4}\left(y^2 + 2y + 1\right) = \cfrac{3}{4}(2x - y + 1)^2 + \cfrac{25}{4}(y + 1)^2 =$
# $= \left(\sqrt{3}x - \cfrac{\sqrt{3}}{2}y + \cfrac{\sqrt{3}}{2}\right)^2 + \left(\cfrac{5}{2}y + \cfrac{5}{2}\right)^2 \Rightarrow A = \begin{pmatrix}
# \sqrt{3} & -\cfrac{\sqrt{3}}{2}\\
# 0 & \cfrac{5}{2}
# \end{pmatrix}, \quad b = \begin{pmatrix}
# \cfrac{\sqrt{3}}{2}\\
# \cfrac{5}{2}
# \end{pmatrix}$
#
# Проверим, что мы нашли правильное аффинное преобразованиеб, т. е. должно быть
#
# $\Sigma_{st} = A \cdot \Sigma \cdot A^{\intercal} = \begin{pmatrix}
# 1 & 0\\
# 0& 1
# \end{pmatrix}, и \quad \begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix} = A \cdot \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} + b = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix}$
#
# $\Sigma_{st} = A \cdot \Sigma \cdot A^{\intercal} = \cfrac{4}{75}\begin{pmatrix}
# \sqrt{3} & -\cfrac{\sqrt{3}}{2}\\
# 0 & \cfrac{5}{2}
# \end{pmatrix} \cdot \begin{pmatrix}
# 7 & 1.5\\
# 1.5 & 3
# \end{pmatrix} \cdot \begin{pmatrix}
# \sqrt{3} & 0\\
# -\cfrac{\sqrt{3}}{2} & \cfrac{5}{2}
# \end{pmatrix} = \begin{pmatrix}
# 1 & 0\\
# 0& 1
# \end{pmatrix}$
#
# $\begin{pmatrix}
# \xi_{st}\\
# \eta_{st}
# \end{pmatrix} = \begin{pmatrix}
# \sqrt{3} & -\cfrac{\sqrt{3}}{2}\\
# 0 & \cfrac{5}{2}
# \end{pmatrix} \cdot \begin{pmatrix}
# -1\\
# -1
# \end{pmatrix} + \begin{pmatrix}
# \cfrac{\sqrt{3}}{2}\\
# \cfrac{5}{2}
# \end{pmatrix} = \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix}$

# %% [markdown]
# ### Задание 3
# Найти ортогональное преобразование, перерводящее соответствующий центрированный слцчай вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения.
#
# Для того, чтобы найти такое преобразование, надо найти собственные вектора
# $\left| \begin{pmatrix}
# 3 & -1.5\\
# -1.5 & 7
# \end{pmatrix}  - \begin{pmatrix}
# 1 & 0\\
# 0 & 1
# \end{pmatrix} \cdot \begin{pmatrix}
# \lambda & 0\\
# 0 & \lambda
# \end{pmatrix} \right| = \left| \begin{pmatrix}
# 3 - \lambda & -1.5\\
# -1.5 & 7 - \lambda
# \end{pmatrix}  \right|$
#
# $(3 - \lambda)(7 - \lambda) - 1.5^2 = 0$
#
# $\lambda^2 - 10\lambda + 18,75 = 0$
#
# $(\lambda - \cfrac{5}{2})(\lambda - \cfrac{15}{2}) = 0$
#
# 1) $\lambda_1 = \cfrac{5}{2}$
#
# $\begin{pmatrix}
# 3 - \lambda_1 & -\cfrac{3}{2}\\
# -\cfrac{3}{2} & 7 - \lambda_1
# \end{pmatrix} = \begin{pmatrix}
# 3 - \cfrac{5}{2} & -\cfrac{3}{2}\\
# -\cfrac{3}{2} & 7 - \cfrac{5}{2}
# \end{pmatrix} = \begin{pmatrix}
# \cfrac{1}{2} & -\cfrac{3}{2}\\
# -\cfrac{3}{2} & \cfrac{9}{2}
# \end{pmatrix}$
#
# $\begin{cases}
# 0.5u_1 - 1.5v_1=0 \\
# -1.5u_1 + 4.5v_1=0
# \end{cases}
# \begin{cases}
# u_1 = 3v_1 \\
# -4.5v_1 + 4.5v_1=0
# \end{cases}\Rightarrow
# \begin{cases}
# v_1 \in \mathbb{R}, v_1 = \alpha\\
# u_1 = 3\alpha
# \end{cases} \Rightarrow
# \vec{u_1} = \begin{pmatrix}
# 3\\
# 1
# \end{pmatrix} \cdot \alpha$
#
# $\alpha =\cfrac{1}{\sqrt{10}} \Rightarrow \vec{u_1} = \cfrac{1}{\sqrt{10}}\begin{pmatrix}
# 3\\
# 1
# \end{pmatrix}$
#
# 2) $\lambda_2 = \cfrac{15}{2}$
#
# $\begin{pmatrix}
# 3 - \lambda_2 & -\cfrac{3}{2}\\
# -\cfrac{3}{2} & 7 - \lambda_2
# \end{pmatrix} = \begin{pmatrix}
# 3 - \cfrac{15}{2} & -\cfrac{3}{2}\\
# -\cfrac{3}{2} & 7 - \cfrac{15}{2}
# \end{pmatrix} = \begin{pmatrix}
# -\cfrac{9}{2} & -\cfrac{3}{2}\\
# -\cfrac{3}{2} & -\cfrac{1}{2}
# \end{pmatrix}$
#
# $\begin{cases}
# -4.5u_2 - 1.5v_2=0 \\
# -1.5u_2 - 0.5v_2=0
# \end{cases}
# \begin{cases}
# -4.5u_2 = -4.5u_2 \\
# v_2 = -3u_2
# \end{cases}\Rightarrow
# \begin{cases}
# u_2 \in \mathbb{R}, u_2 = \beta\\
# v_2 = -3\beta
# \end{cases} \Rightarrow
# \vec{v_2} = \begin{pmatrix}
# 1\\
# -3
# \end{pmatrix} \cdot \beta$
#
# $\beta =\cfrac{1}{\sqrt{10}} \Rightarrow \vec{v_2} = \cfrac{1}{\sqrt{10}}\begin{pmatrix}
# 1\\
# -3
# \end{pmatrix}$
#
# $ Q^{\intercal} = \cfrac{1}{\sqrt{10}} \left( \begin{matrix}
# 3 & 1 \\
# 1 & -3
# \end{matrix} \right) \Rightarrow Q = \cfrac{1}{\sqrt{10}} \left( \begin{matrix}
# 3 & 1 \\
# 1 & -3
# \end{matrix} \right)$
#
# $ \Sigma_{id} = Q \Sigma Q^{\intercal} = \cfrac{4}{750}\begin{pmatrix}
# 3 & 1 \\
# 1 & -3
# \end{pmatrix} \cdot \begin{pmatrix}
# 7 & 1.5 \\
# 1.5 & 3
# \end{pmatrix} \cdot \begin{pmatrix}
# 3 & 1 \\
# 1 & -3
# \end{pmatrix} = \begin{pmatrix}
# \cfrac{4}{10} & 0 \\
# 0 & \cfrac{4}{30}
# \end{pmatrix} \Rightarrow \Sigma_{id}^{-1} = \begin{pmatrix}
# \cfrac{5}{2} & 0 \\
# 0 & \cfrac{15}{2}
# \end{pmatrix}$
#
# $\begin{pmatrix}
# \xi_{id}\\
# \eta_{id}
# \end{pmatrix}^{\intercal} = \begin{pmatrix}
# \xi_{id} &\eta_{id}
# \end{pmatrix} \cdot Q = \begin{pmatrix}
# -1 &-1
# \end{pmatrix} \cdot \cfrac{1}{\sqrt{10}} \left( \begin{matrix}
# 3 & 1 \\
# 1 & -3
# \end{matrix} \right) = \cfrac{1}{\sqrt{10}}\begin{pmatrix}
# -4 & 2
# \end{pmatrix} \Rightarrow \begin{pmatrix}
# \xi_{id}\\
# \eta_{id}
# \end{pmatrix} = \begin{pmatrix}
# \cfrac{-4}{\sqrt{10}}\\
# \cfrac{2}{\sqrt{10}}
# \end{pmatrix}$
#
# Тогда полученное распределение будет выглядеть следующим образом:
#
# $p_{\xi, \eta}(x, y) = C \cdot \exp \left(-\cfrac{1}{2}\left(\overrightarrow{x}-\mu\right)^{\intercal}\Sigma^{-1}\left(\overrightarrow{x}-\mu\right)\right), \quad C = \cfrac{1}{(2\pi)^{\cfrac{n}{2}}\sqrt{det \Sigma_{id}}} = \cfrac{\sqrt{3}}{15\pi} \Rightarrow$
#
# $p_{\xi, \eta}(x, y) = \cfrac{\sqrt{3}}{15\pi} \cdot \exp{\left(-\cfrac{1}{2}\left(\begin{pmatrix}
# x - \cfrac{-4}{\sqrt{10}}\\
# y - \cfrac{2}{\sqrt{10}}
# \end{pmatrix}^{\intercal} \cdot \begin{pmatrix}
# \cfrac{5}{2} & 0 \\
# 0 & \cfrac{15}{2}
# \end{pmatrix} \cdot \begin{pmatrix}
# x - \cfrac{-4}{\sqrt{10}}\\
# y - \cfrac{2}{\sqrt{10}}
# \end{pmatrix}\right)\right)} =$
#
# $= \cfrac{\sqrt{3}}{15\pi} \cdot \exp{\left(-\cfrac{1}{2}\left(\cfrac{5}{2}x^2 + \cfrac{15}{2}y^2 + 2\sqrt{10}x - 3\sqrt{10}y + 7\right)\right)}$

# %% [markdown]
# ### График плотности распределения

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Определяем область значений для x и y
x = np.linspace(-3, 3, 50)
y = np.linspace(-3, 3, 50)

# Создаем сетку координат
X, Y = np.meshgrid(x, y)

# Вычисляем значения функции
Z = (np.sqrt(3) / (15 * np.pi)) * np.exp(-1/2 * (5/2 * X**2 + 15/2 * Y**2 + 2 * np.sqrt(10) * X - 3 * np.sqrt(10) * Y + 7))

# Создаем 3D-график
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.viridis)

# Настраиваем оси
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('P(x, y)')

# Отображаем график
#ax.set(title="")
plt.show()

# %% [markdown]
# ### Задание 4
# Вычислить характеристики совместного распределения случайного вектора $\left(2\xi + \eta, -3\xi + 2\eta\right)^{\intercal}$ и записать его плотность. Построить график плотности полученного распределения.
#
# $\left(2\xi + \eta, -3\xi + 2\eta\right)^{\intercal} =
# \begin{pmatrix}
# 2 & 1\\
# -3 & 2
# \end{pmatrix} \begin{pmatrix}
# \xi\\
# \eta
# \end{pmatrix} + \begin{pmatrix}
# 0\\
# 0
# \end{pmatrix} $
#
# Матрица $A$ невырожденная, т.к. $ \det A = 4 + 3 = 7 \neq 0 $
#
# $ \vec{\mu} =
# \begin{pmatrix}
# 2 & 1\\
# -3 & 2
# \end{pmatrix} \begin{pmatrix}
# -1 \\
# -1
# \end{pmatrix} = \begin{pmatrix}
# -3 \\
# 1
# \end{pmatrix}$
#
# $\Sigma = \cfrac{4}{75} \begin{pmatrix}
# 2 & -3\\
# 1 & 2
# \end{pmatrix} \begin{pmatrix}
# 7 & 1.5 \\
# 1.5 & 3
# \end{pmatrix} \begin{pmatrix}
# 2 & 1\\
# -3 & 2
# \end{pmatrix} = \cfrac{4}{75}\begin{pmatrix}
# 37 & -2.5 \\
# -2.5 & 25
# \end{pmatrix} \Rightarrow \Sigma^{-1} = \begin{pmatrix}
# \cfrac{148}{75} & -\cfrac{2}{15} \\
# -\cfrac{2}{15} & \cfrac{4}{3}
# \end{pmatrix}$
#
# $ \mathbb{D} \xi = \cfrac{148}{75}, \quad \mathbb{D} \eta = \cfrac{4}{3}$
#
# $\mathop{\mathrm{cov}}\nolimits(\xi, \eta) = -\cfrac{2}{15}$
#
# $\rho_{\xi, \eta} = -\cfrac{\sqrt{37}}{74}$
#
# $C = \cfrac{1}{(2\pi)^{\cfrac{n}{2}}\sqrt{det \Sigma}} = \cfrac{5\sqrt{3}}{28\pi}$
#
# Распределение будет выглядеть следующим образом:
#
# $ p_{\xi, \eta}(x, y) = \cfrac{5\sqrt{3}}{28\pi} \cdot \exp{\left(-\cfrac{1}{2}\begin{pmatrix}
# x + 3 \\
# y - 1
# \end{pmatrix}^{\intercal} \begin{pmatrix}
# \cfrac{148}{75} & -\cfrac{2}{15} \\
# -\cfrac{2}{15} & \cfrac{4}{3}
# \end{pmatrix} \begin{pmatrix}
# x + 3 \\
# y - 1
# \end{pmatrix}\right)}$
#
# $p_{\xi, \eta}(x, y) = \cfrac{5\sqrt{3}}{28\pi} \cdot \exp{\left(-\cfrac{1}{2}\left(\cfrac{148}{75}x^2 + \cfrac{4}{3}y^2 - \cfrac{4}{15}xy + \cfrac{908}{75}x - \cfrac{52}{15}y + \cfrac{1492}{75}\right)\right)}$

# %% [markdown]
# ### График плотности распределения

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# Определяем область значений для x и y
x = np.linspace(-7, 1, 50)
y = np.linspace(-3, 6, 50)

# Создаем сетку координат
X, Y = np.meshgrid(x, y)

# Вычисляем значения функции
Z = (np.sqrt(3)/(15*np.pi))*np.exp(-1/2*((148/75)*X**2 + (4/3)*Y**2 - (4/15)*X*Y + (908/75)*X - (52/15)*Y + (1492/75)))

# Создаем 3D-график
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap=cm.viridis)

# Настраиваем оси
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('P(x, y)')

# Отображаем график
#ax.set(title="")
plt.show()

# %% [markdown]
# ### Задание 5
# Найти условное распределение $\xi$ при условии $\eta$.
# Вычислить $\mathbb{E}$ и $\mathbb{D}$
#
# Распределение $\eta$ при условии $\xi$ будет выглядеть следующим образом:
#
# $p_{\eta}(y) = \cfrac{1}{\sqrt{2\pi}\sigma_\eta}\cdot \exp{\left(-\cfrac{1}{2}\left(\cfrac{y - a_n}{\sigma_\eta}\right)^2\right)}$
#
# $ p_{\xi|\eta=y_0} (x) = \cfrac{p_{\xi, \eta}(x, y_0)}{p_\eta(y_0)} = \cfrac{\cfrac{5\sqrt{3}}{4\pi} \cdot \exp\left(-\frac{1}{2}\left(3x^2-3xy_0+7y_0^2+11y_0+3x+7\right)\right)}{\cfrac{1}{\sqrt{2\pi}\sqrt{\cfrac{4}{25}}}\cdot \exp{\left(-\cfrac{1}{2}\left(\cfrac{y_0 - 2}{\sqrt{\cfrac{4}{25}}}\right)^2\right)}} = $
#
# $= \cfrac{5\sqrt{3}}{4\pi} \cdot \sqrt{2\pi} \cdot \exp{\left(-\cfrac{1}{2}\left(3x^2 - 3xy_0 + 7y_0^2 + 3x + 11y_0 + 7 - \left(\cfrac{y_0 - 2}{\sqrt{\cfrac{4}{25}}}\right)^2\right)\right)} =$
#
# $= \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp{\left(-\cfrac{1}{2}\left(3x^2 - 3xy_0 + \cfrac{3}{4}y_0^2 - \cfrac{6}{4}y_0 + \cfrac{3}{4} + 3x\right)\right)} = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp{\left(-\cfrac{1}{2}\left(3\left(x^2 - xy_0 + \cfrac{1}{4}y_0^2 - \cfrac{1}{2}y_0 + \cfrac{1}{4} + x\right)\right)\right)} = $
#
# $= \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp{\left(-\cfrac{1}{2}\left(\cfrac{x + \left(\cfrac{1}{2}y_0 - \cfrac{1}{2}\right)}{\cfrac{1}{\sqrt{3}}}\right)\right)} \Rightarrow p_{\xi|\eta}(x) = \cfrac{\sqrt{3}}{\sqrt{2\pi}} \cdot \exp{\left(-\cfrac{1}{2}\left(\cfrac{x + \left(\cfrac{1}{2}y - \cfrac{1}{2}\right)}{\cfrac{1}{\sqrt{3}}}\right)\right)}$
#
# $ \mathbb{E} (\xi|\eta) = -\left(\cfrac{1}{2}y - \cfrac{1}{2}\right)$
#
# $\mathbb{D} (\xi|\eta) = \left( \cfrac{1}{\sqrt{3}} \right)^2 = \cfrac{1}{3} $

# %% [markdown]
# ## Выводы
#
# Во время выполнения практической рабоыт были исследованы свойства двумерного случайного вектора имеющего нормальное распределение, также были получены навыки преобразования нормального вектора в стандартный и в вектор с независимыми компонентами. Получилось разобраться в том, как раюотать в jupyter notebook и в том числе, как работать с формулами LaTeX. Были получены умения и навыки, как строить график распредления случайной величины на языке Python и как настраивать оси.
