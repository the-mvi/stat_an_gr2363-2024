# %% [markdown]
# # Практическая работа №1: Исследование двумерного нормального распределения
#
# Выполнил студент гр. 2363 Лушев Андрей Александрович. Вариант №8

# %% [markdown]
# ## Цель работы
# Исследовать свойства двумерного случайного вектора имеющего нормальное распределение, овладеть навыками преобразования нормального вектора в стандартный и в вектор с независимыми компонентами.

# %% [markdown]
# ## Постановка задачи
# Для заданного двумерного нормального вектора необходимо вычислить числовые характеристики и выполнить заданные преобразования. Полученные результаты содержательно проинтерпретировать.

# %% [markdown]
# ## Основные теоретические положения
#
# Нормальное распределение двумерного случайного вектора определяется функцией плотности:
# $p(\vec{x}) = \frac{1}{2\pi \cdot \sqrt{\begin{vmatrix} \Sigma \end{vmatrix}}} \exp\left( -\frac{1}{2} \cdot (\vec{x} - \vec{\mu})^{\intercal} \cdot \Sigma^{-1} \cdot (\vec{x} - \vec{\mu}) \right), $
# где: $\vec{x}=\left(\begin{matrix}
# \xi \\
# \eta
# \end{matrix}\right),
# \vec{\mu} = \mathbb{E}\left(\begin{matrix}
# \xi \\
# \eta
# \end{matrix}\right),
# \Sigma = \left(\begin{matrix}
# \mathbb{D}\xi & \mathop{\mathrm{cov}}\limits(\xi, \eta) \\
# \mathop{\mathrm{cov}}\limits(\eta, \xi) & \mathbb{D}\eta
# \end{matrix}\right).$

# %% [markdown]
# Аффинные преобразования:

# %% [markdown]
# $\vec{\xi} \sim \mathcal{N}(\vec{\mu}, \Sigma)$ - случайный вектор;

# %% [markdown]
# $\vec{\xi}_{st} \sim\mathcal{N}(\vec{\mu}_{st}, \Sigma_{st})$ — стандартный нормальный случайный вектор;

# %% [markdown]
# $\vec{\xi}_{st} = A \cdot\vec{\xi} + b$ — афинное преобразование случайного вектора;

# %% [markdown]
# $A\cdot\vec{\xi}+b \sim \mathcal{N}(A\cdot\vec{\mu}+b, A\cdot\Sigma \cdot A^{\intercal})$

# %% [markdown]
# где
# $\vec{\mu}_{st}=A\cdot\vec{\mu}+b ; \Sigma_{st} = A\cdot\Sigma \cdot A^{\intercal}$

# %% [markdown]
# Ортогональные преобразования:

# %% [markdown]
# $Q^{\intercal}$ — матрица из собственных векторов матрицы $\Sigma$

# %% [markdown]
# $Q \cdot \Sigma \cdot Q^{\intercal} = D$

# %% [markdown]
# где: $D=\left(\begin{matrix} \frac{1}{\lambda_{1}} & 0 \\ 0 & \frac{1}{\lambda_{2}} \end{matrix}\right).$

# %% [markdown]
# $p_{\xi,\eta}(x', y') = \frac{1}{2\pi \cdot \sqrt{ det\Sigma}} \cdot \exp\left(-\frac{1}{2} \cdot \left[  \left(\begin{matrix} x' & y' \end{matrix}\right) \cdot D^{-1} \cdot \left(\begin{matrix} x' \\ y' \end{matrix}\right) \right]\right)$ - плотность распределения

# %% [markdown]
# Cовместное распределение случайного вектора:

# %% [markdown]
# $\vec{b} = A \cdot \left(\begin{matrix} \xi \\ \eta \end{matrix}\right)$ — случайный вектор,

# %% [markdown]
# $\vec{b} \sim \mathcal{N}(A \cdot \vec{\mu}, A \cdot \Sigma \cdot A^{\intercal})$

# %% [markdown]
# Условное распределение:

# %% [markdown]
# $\xi | \eta = y \sim \mathcal{N}(\mathbb{E}[\xi|\eta], \mathbb{D}[\xi|\eta])$

# %% [markdown]
# $\mathbb{E}[\xi|\eta] = \mu_{\xi} + \frac{cov({\xi}{\eta})}{\mathbb{D}_{\eta}} \cdot (y - \mu_{\eta})$

# %% [markdown]
# $\mathbb{D}[\xi|\eta] = \mathbb{D}_{\xi} - \frac{cov({\xi}{\eta})^2}{\mathbb{D}_{\eta}}$

# %% [markdown]
# 1. Вычислить вектор математических ожиданий и ковариационные характеристики данного случайного вектора. Построить график плотности распределения $p_{\xi,\eta}$

# %% [markdown]
# $p_{\xi,\eta}(x,y)= C \cdot \exp\left(-\frac{1}{2} (5x^2 -6xy + 13y^2 + 14x + 14y + 21) \right)$

# %% [markdown]
# $5x^2 -6xy + 13y^2 + 14x + 14y + 21$

# %% [markdown]
# $5\left(x^2 -\frac{6}{5}xy \right)+ 13y^2 + 14x + 14y + 21$

# %% [markdown]
# $5\left(x^2 -2\cdot\frac{3}{5}xy + \frac{9}{25}y^2\right)+ \frac{56}{5}y^2 + 14x + 14y + 21$

# %% [markdown]
# $5\left(x -\frac{3}{5}y\right)^2 + \frac{56}{5}y^2 + 14\left(x - \frac{3}{5}y \right) + \frac{112}{5}y + 21$

# %% [markdown]
# $5\left(\left(x -\frac{3}{5}y\right)^2 + \frac{14}{5}(x - \frac{3}{5}y)\right) + \frac{112}{5}y + 21 + \frac{56}{5}y^2$

# %% [markdown]
# $5\left(\left(x -\frac{3}{5}y\right)^2 + 2 \cdot \frac{7}{5}(x - \frac{3}{5}y) + \frac{49}{25}\right) + \frac{112}{5}y + \frac{56}{5} + \frac{56}{5}y^2$

# %% [markdown]
# $5\left(\left(x -\frac{3}{5}y\right) + \frac{7}{5}\right)^2 + \frac{56}{5}\left(y + 1 \right)^2$ (используем во втором пункте с аффинными преобразованиями)

# %% [markdown]
# $ 5\left(x - \frac{3}{5}y - \frac{3}{5} + \frac{10}{5} \right)^2+ \frac{56}{5}\left(y + 1 \right)^2$

# %% [markdown]
# $ 5\left((x +2) - \frac{3}{5}(y + 1) \right)^2+ \frac{56}{5}\left(y + 1 \right)^2$

# %% [markdown]
# $5(x+2)^2 + 2 \cdot (-3)(x+2)(y+1) + 13(y+1)^2$

# %% [markdown]
# $\vec{\mu}_\xi,_\eta = \left(\begin{matrix}
#   -2 \\
#   -1
#  \end{matrix}\right) $

# %% [markdown]
# $\Sigma^{-1}=
# \left(
#  \begin{matrix}
#   5 & -3 \\
#   -3 & 13
#  \end{matrix}
# \right)$

# %% [markdown]
# $\Sigma = \frac{1}{56}
# \left(
#  \begin{matrix}
#   13 & 3 \\
#   3 & 5
#  \end{matrix}
# \right)
# $

# %% [markdown]
# $\mathbb{D}_\xi = \frac{5}{56} ; \mathbb{D}_\eta = \frac{13}{56} ; \mathop{\mathrm{cov}}\nolimits(\xi, \eta) = \frac{3}{56}$

# %% [markdown]
# $\rho(\xi, \eta) = \frac{\mathop{\mathrm{cov}}\nolimits(\xi, \eta) }{\sqrt{\mathbb{D}_\xi \mathbb{D}_\eta}}= \frac{3}{\sqrt{65}}$

# %% [markdown]
# $C=\frac{1}{2\pi\sqrt{\frac{1}{56}}}=\frac{\sqrt{14}}{\pi}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def p(x, y):
    return (14**0.5 / np.pi) * np.exp(-0.5 * (5*x**2 - 6*x*y + 13*y**2 + 14*x + 14*y + 21))

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = p(X, Y)

fig = plt.figure()
g = fig.add_subplot(111, projection='3d')
g.plot_surface(X, Y, Z, cmap='viridis')
g.set_xlabel('X')
g.set_ylabel('Y')
g.set_zlabel('p(X, Y)')
g.set_title('График плотности распределения p(X, Y)')
plt.show()

# %% [markdown]
# 2. Выполнить аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный

# %% [markdown]
# $5\left(\left(x -\frac{3}{5}y\right) + \frac{7}{5}\right)^2 + \frac{56}{5}\left(y + 1 \right)^2$

# %% [markdown]
# $\left(\sqrt{5}x -\frac{3\sqrt{}5}{5}y + \frac{7\sqrt{5}}{5}\right)^2 + \left(\sqrt{\frac{56}{5}}y +  \sqrt{\frac{56}{5}}\right)^2$

# %% [markdown]
# $\left(
#  \begin{matrix}
#   \sqrt{5} & -\frac{3\sqrt{5}}{5} \\
#   0 & \sqrt{\frac{56}{5}}
#  \end{matrix}
# \right)\cdot \left(\begin{matrix}
#   -2 \\
#   -1
#  \end{matrix}\right)+ \left(\begin{matrix}
#   \frac{7\sqrt{5}}{5} \\
#   \sqrt{\frac{56}{5}}
#  \end{matrix}\right) = \left(\begin{matrix}
#   -2\sqrt{5} +2\sqrt{5} \\
#   \sqrt{\frac{56}{5}} -\sqrt{\frac{56}{5}}
#  \end{matrix}\right) = \left(\begin{matrix}
#   0\\
#   0
#  \end{matrix}\right)$

# %% [markdown]
# $\frac{1}{56}
# \left(
#  \begin{matrix}
#   \sqrt{5} & -\frac{3\sqrt{5}}{5} \\
#   0 & \sqrt{\frac{56}{5}}
#  \end{matrix}
# \right)
# \cdot
# \left(
#  \begin{matrix}
#   13 & 3 \\
#   3 & 5
#  \end{matrix}
# \right)
# \cdot
# \left(
#  \begin{matrix}
#   \sqrt{5} & 0 \\
#   -\frac{3\sqrt{5}}{5} & \sqrt{\frac{56}{5}}
#  \end{matrix}
# \right) =
# \left(
#  \begin{matrix}
#   1 & 0 \\
#   0 & 1
#  \end{matrix}
# \right)
# $

# %% [markdown]
# 3. Найти ортогональное преобразование, переводящее соответствующий центрированный случайный вектор в вектор с независимыми компонентами. Построить график плотности полученного распределения

# %% [markdown]
# $
# \left|
# \left(
#  \begin{matrix}
#   5 & -3 \\
#   -3 & 13
#  \end{matrix}
# \right)
# - \left(
#  \begin{matrix}
#   \lambda & 0 \\
#   0 & \lambda
#  \end{matrix}
# \right)
# \right| \sim
# \left|
#  \begin{matrix}
#   5-\lambda & -3 \\
#   -3 & 13 -\lambda
#  \end{matrix}
# \right| = 0
# $

# %% [markdown]
# $(5-\lambda)(13-\lambda)-9=0$

# %% [markdown]
# $65-5\lambda-13\lambda+\lambda^2 -9=0$

# %% [markdown]
# $\lambda^2-18\lambda+56=0$

# %% [markdown]
# $D=(-18)^2-4\cdot1\cdot56= 324-224=100$

# %% [markdown]
# $\lambda_1 = \frac{18+10}{2}=14 \;\; \lambda_2 = \frac{18-10}{2}=4 $

# %% [markdown]
# $\lambda_1
#   \begin{cases}
#     -9u_1 -3v_1 =0\\
#     -3u_1 -1v_1 =0
#   \end{cases} \Rightarrow
#   \begin{cases}
#     v_1=-3u_1\\
#     -3u_1 +3u_1=0
#   \end{cases} \Rightarrow
#   \begin{cases}
#     \alpha \in \mathbb{R}; u_1=\alpha\\
#     v_1=-3\alpha
#   \end{cases}
#   $

# %% [markdown]
# $\lambda_2
#   \begin{cases}
#     u_2 -3v_2 =0\\
#     -3u_2 +9v_2 =0
#   \end{cases} \Rightarrow
#   \begin{cases}
#     u_2=3v_2\\
#     -9u_1 +9u_1=0
#   \end{cases} \Rightarrow
#   \begin{cases}
#     \beta \in \mathbb{R}; v_2=\beta\\
#     u_2=3\beta
#   \end{cases}
#   $

# %% [markdown]
# $|u|=\sqrt{1^2+3^2} \; |v|=\sqrt{1^2+(-3)^2}$

# %% [markdown]
# $
# u=\frac{1}{\sqrt{10}}\left(\begin{matrix}
#   1 \\
#   -3
#  \end{matrix}\right)
# \; v=\frac{1}{\sqrt{10}}\left(\begin{matrix}
#   3 \\
#   1
#  \end{matrix}\right)
# $

# %% [markdown]
# $Q^{\intercal}=\frac{1}{\sqrt{10}}
# \left(
#  \begin{matrix}
#   1 & 3 \\
#   -3 & 1
#  \end{matrix}
# \right) \;
# Q = \frac{1}{\sqrt{10}}
# \left(
#  \begin{matrix}
#   1 & -3 \\
#   3 & 1
#  \end{matrix}
# \right)
# $

# %% [markdown]
# $Q\cdot\Sigma \cdot Q^{\intercal} =\frac{1}{10\cdot 56}
# \left(
#  \begin{matrix}
#   1 & -3 \\
#   3 & 1
#  \end{matrix}
# \right)
# \cdot
# \left(
#  \begin{matrix}
#   13 & 3 \\
#   3 & 5
#  \end{matrix}
# \right)
# \cdot
# \left(
#  \begin{matrix}
#   1 & 3 \\
#   -3 & 1
#  \end{matrix}
# \right) =
# \left(
#  \begin{matrix}
#   \frac{1}{14} & 0 \\
#   0 & \frac{1}{4}
#  \end{matrix}
# \right)
# $

# %% [markdown]
# $D=\left(
#  \begin{matrix}
#   \frac{1}{14} & 0 \\
#   0 & \frac{1}{4}
#  \end{matrix}
# \right)$

# %% [markdown]
# $D^{-1}=56\cdot\left(
#  \begin{matrix}
#   \frac{1}{4} & 0 \\
#   0 & \frac{1}{14}
#  \end{matrix}
# \right)=
# \left(
#  \begin{matrix}
#   14 & 0 \\
#   0 & 4
#  \end{matrix}
# \right)$

# %% [markdown]
# $p_{\xi,\eta}(x', y') = \frac{1}{2\pi \cdot \sqrt{ det\Sigma }} \cdot \exp\left(-\frac{1}{2} \cdot\left[\left(\begin{matrix}
# x' & y' \end{matrix}\right) \cdot D^{-1} \cdot \left(\begin{matrix}
# x'\\ y' \end{matrix}\right)\right]\right) = \frac{\sqrt{14}}{\pi} \cdot\exp\left(-\frac{1}{2} \cdot\left[ 14{x'}^2 + 4{y'}^2\right]\right).$

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def p(x, y):
    return (14**0.5 / np.pi) * np.exp(-0.5 * (14*x**2 + 4*y**2 ))

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = p(X, Y)

fig = plt.figure()
g = fig.add_subplot(111, projection='3d')
g.plot_surface(X, Y, Z, cmap='viridis')
g.set_xlabel('X')
g.set_ylabel('Y')
g.set_zlabel('p(X, Y)')
g.set_title('График плотности распределения p(X, Y)')
plt.show()

# %% [markdown]
# 4. Вычислить характеристики совместного распределения случайного вектора $(-3\xi -2\eta, -3\xi- 5\eta)^T$ и записать его плотность. Построить график плотности полученного распределения

# %% [markdown]
# $(-3\xi -2\eta, -3\xi- 5\eta)^{\intercal}$

# %% [markdown]
# $\begin{cases}
#    \mathbb{E}(x)\\
#     \mathbb{E}(y)
#   \end{cases} \Rightarrow
#   \begin{cases}
#    \mathbb{E}(-3\xi -2\eta)\\
#    \mathbb{E}(-3\xi -5\eta)
#   \end{cases} \Rightarrow
#   \begin{cases}
#    -3\mathbb{E}(\xi)-2\mathbb{E}(\eta)\\
#    -3\mathbb{E}(\xi)-5\mathbb{E}(\eta)
#   \end{cases} \Rightarrow
#   \begin{cases}
#    \mathbb{E}(x)=8\\
#    \mathbb{E}(y)=11
#   \end{cases}
#   $

# %% [markdown]
# $\begin{cases}
#    \mathbb{D}(x)\\
#     \mathbb{D}(y)
#   \end{cases} \Rightarrow
#   \begin{cases}
#    \mathbb{D}(-3\xi -2\eta)\\
#    \mathbb{D}(-3\xi -5\eta)
#   \end{cases} \Rightarrow
#   \begin{cases}
#    9\mathbb{D}(\xi)+4\mathbb{D}(\eta)\\
#    9\mathbb{D}(\xi)+25\mathbb{D}(\eta)
#   \end{cases} \Rightarrow
#   \begin{cases}
#    \mathbb{D}(x)=\frac{13}{56}\\
#    \mathbb{D}(y)=\frac{34}{56}
#   \end{cases}
#   $

# %% [markdown]
# $\mathop{\mathrm{cov}}\nolimits(-3\xi-2\eta,-3\xi-5\eta)=\mathbb{E}((-3\xi-2\eta)(-3\xi-5\eta))-\mathbb{E}(-3\xi-2\eta)\cdot\mathbb{E}(-3\xi-5\eta)$

# %% [markdown]
# $\mathbb{E}(9\xi^2+15\xi\eta+6\xi\eta+10\eta^2)-\mathbb{E}(-3\xi-2\eta)\cdot\mathbb{E}(-3\xi-5\eta)$

# %% [markdown]
# $9\mathbb{D}(\xi)+10\mathbb{D}(\eta)+21\mathbb{E}(\xi\cdot\eta)-\mathbb{E}(-3\xi-2\eta)\cdot\mathbb{E}(-3\xi-5\eta)$

# %% [markdown]
# $9\mathbb{D}(\xi)+10\mathbb{D}(\eta)+21(\mathbb{E}(\xi\eta)-\mathbb{E}(\xi)\cdot\mathbb{E}(\eta))$

# %% [markdown]
# $9\frac{1}{56}+10\frac{1}{56}=\frac{19}{56}$

# %% [markdown]
# $\Sigma=\frac{1}{56}
# \left(
#  \begin{matrix}
#   13 & 19 \\
#   19 & 34
#  \end{matrix}
# \right)$

# %% [markdown]
# $p_\xi,_\eta(x,y)= \frac{56}{2\pi9} \cdot \exp\left(-\frac{1}{2}\cdot \frac{1}{81}\cdot (1904x^2 -2128xy + 728y^2 - 7056x + 1008y + 22680) \right)$

# %% [markdown]
# $\frac{1}{81}
# \left(
#  \begin{matrix}
#   1904 & -1064 \\
#   -1064 & 728
#  \end{matrix}
# \right)^{-1} = \frac{1}{56}
# \left(
#  \begin{matrix}
#   13 & 19 \\
#   19 & 34
#  \end{matrix}
# \right)$

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def p(x, y):
    return (28 / 9 * np.pi) * np.exp(-0.5 * (1/81)* (1904*x**2 -2128*x*y + 728*y**2 -7056*x +1008*y+22680))

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
Z = p(X, Y)

fig = plt.figure()
g = fig.add_subplot(111, projection='3d')
g.plot_surface(X, Y, Z, cmap='viridis')
g.set_xlabel('X')
g.set_ylabel('Y')
g.set_zlabel('p(X, Y)')
g.set_title('График плотности распределения p(X, Y)')
plt.show()

# %% [markdown]
# 5. Найти условное распределение $\xi$ при условии $\eta$. Вычислить $\mathbb{E}[\xi|\eta]$ и $\mathbb{D}[\xi|\eta]$.

# %% [markdown]
# $\mathbb{E}[\xi|\eta] = \mu_{\xi} + \frac{cov({\xi}{\eta})}{\mathbb{D}_{\eta}} \cdot (y - \mu_{\eta})$

# %% [markdown]
# $\mathbb{D}[\xi|\eta] = \mathbb{D}_{\xi} - \frac{cov({\xi}{\eta})^2}{\mathbb{D}_{\eta}}$

# %% [markdown]
# $\mathbb{E}[\xi|\eta] = -2 + \frac{\frac{3}{56}}{\frac{13}{56}} \cdot (y_{0} + 1) = - 2 + \frac{3}{13} \cdot (y_{0} + 1) = - 2 +\frac{3}{13} \cdot y_{0} +\frac{3}{13} = -\frac{23}{13} +\frac{3}{13} \cdot y_{0}$

# %% [markdown]
# $\mathbb{D}[\xi|\eta] = \frac{5}{56} - \frac{(\frac{3}{56})^2}{\frac{13}{56}} = \frac{5}{56} - \frac{\frac{9}{3136}}{\frac{13}{56}} = \frac{5}{56} - \frac{9}{728} = \frac{1}{13}$

# %% [markdown]
# $\xi | \eta = y_{0} \sim \mathcal{N}(-\frac{23}{13} +\frac{3}{13} \cdot y_{0}, \frac{1}{13})$

# %% [markdown]
# $p_{\xi|\eta = y_{0}}(x) = \frac{1}{\sqrt{2\pi \sigma_{\xi|\eta}^2}}
# \exp(-\frac{(x - \mu_{\xi|\eta = y_{0}})^2}{2\sigma_{\xi|\eta}^2})$

# %% [markdown]
# $p_{\xi|\eta = y_{0}}(x) = \frac{1}{\sqrt{2\pi \cdot \frac{1}{13}}} \exp\left( -\frac{\left(x -\left(-\frac{23}{13} +\frac{3}{13} \cdot y_{0}\right)\right)^2}{2 \cdot \frac{1}{13}}\right).$

# %% [markdown]
# # Выводы

# %% [markdown]
# В ходе выполнения задания были проведены следующие шаги. Вычисление вектора математических ожиданий и ковариационной матрицы. Был вычислен вектор математических ожиданий для случайного вектора. Была вычислена ковариационная матрица для случайного вектора. Построение графика плотности распределения. Был построен график плотности распределения исходного случайного вектора. Аффинное преобразование в стандартный нормальный вектор. Было выполнено аффинное преобразование, переводящее исходный случайный вектор в стандартный нормальный вектор. Ортогональное преобразование в вектор с независимыми компонентами. Было найдено ортогональное преобразование, переводящее центрированный случайный вектор в вектор с независимыми компонентами. Был построен график плотности распределения полученного вектора. Вычисление характеристик совместного распределения и его плотности. Были вычислены характеристики совместного распределения случайного вектора. Была записана плотность совместного распределения. Был построен график плотности полученного распределения. Нахождение условного распределения и вычисление математического ожидания и дисперсии: было найдено условное распределение при заданном условии. Были вычислены математическое ожидание и дисперсия условного распределения.
